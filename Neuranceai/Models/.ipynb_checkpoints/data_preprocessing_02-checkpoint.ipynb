# %% [markdown]
# <h1> 1 Installing Libraries </h1>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
port matplotlib.pyplot as plt
from subprocess import check_output
# %matplotlib inline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

import os
import gc
import json
import pickle
import glob

import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from bs4 import BeautifulSoup

import tensorflow as tf

import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from subprocess import check_output
# %matplotlib inline
import os
import gc

import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from bs4 import BeautifulSoup
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from bs4 import BeautifulSoup
from fuzzywuzzy import fuzz
from sklearn.manifold import TSNE

from os import path
from PIL import Image

# %%
glove_path = 'E:\All Video\MLDL\glove'

# %%
def load_txt(name):
    with open(name, "r") as f:
        return f.read()

def load_pickle(name):
    with open(name, "rb") as handle:
        return pickle.load(handle)
    
def dump_pickle(name, file):
    with open(name, "wb") as handle:
        pickle.dump(file, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
drug_train_data = pd.read_csv("drug_preprocess.csv", index_col="Unnamed: 0")
drug_train_data.head(2)
# Out:
#        patient_id name_of_drug use_case_for_drug  \
# 10091      223808  Depakote ER          Epilepsy
# 1009        35602      Anexsia              Pain
#
#                                        review_by_patient  \
# 10091  "After trying 4 different meds this one was th...
# 1009   "Worked better than Tylenol w/codeine #3 and C...
#
#        effectiveness_rating drug_approved_by_UIC  number_of_times_prescribed  \
# 10091                     8             1-Apr-08                          15
# 1009                     10             1-Apr-08                          19
#
#        base_score  review_len  review_n_words  \
# 10091    7.633384         370              74
# 1009     6.127475          88              14
#
#                                 review_by_patient_filter  \
# 10091  after trying 4 different meds this one was the...
# 1009   worked better than tylenol w codeine  3 and ca...
#
#                            review_by_patient_unique_word  \
# 10091  ['one', 'gladly', 'stayed', 'scary', 'well', '...
# 1009   ['w', 'tylenol', '3', 'better', 'pain', 'caris...
#
#        len_review_by_patient_unique_word
# 10091                                 35
# 1009                                  10

# %%
# To get the results in 4 decemal points
SAFE_DIV = 0.0001 

STOP_WORDS = stopwords.words("english")
stopword = set(STOP_WORDS)
stopword.add("said")
stopword.add("br")
stopword.add(" ")
stopword.remove("not")
stopword.remove("no")


def preprocess(x):
    x = str(x).lower()
    x = x.replace(",000,000", "m").replace(",000", "k").replace("′", "'").replace("’", "'")\
                           .replace("won't", "will not").replace("cannot", "can not").replace("can't", "can not")\
                           .replace("n't", " not").replace("what's", "what is").replace("it's", "it is")\
                           .replace("'ve", " have").replace("i'm", "i am").replace("'re", " are")\
                           .replace("he's", "he is").replace("she's", "she is").replace("'s", " own")\
                           .replace("%", " percent ").replace("₹", " rupee ").replace("$", " dollar ")\
                           .replace("€", " euro ").replace("'ll", " will").replace("asap", "as soon as possible")
    x = re.sub(r"([0-9]+)000000", r"\1m", x)
    x = re.sub(r"([0-9]+)000", r"\1k", x)
    
    
    porter = PorterStemmer()
    pattern = re.compile('\W')
    
    if type(x) == type(''):
        x = re.sub(pattern, ' ', x)
    
    
    if type(x) == type(''):
        x = porter.stem(x)
        example1 = BeautifulSoup(x)
        x = example1.get_text()
               
    return x
def combine_name_use_review(a, b, c):
    return preprocess(" ".join([a, b, c]))

# %% [markdown]
# <h1>2 Combine Name Use case and Review </h1>

# %%
drug_train_data["combine_name_use_review"] = drug_train_data.loc[:, ["name_of_drug", "use_case_for_drug", "review_by_patient_filter"]].fillna("").apply(lambda x: combine_name_use_review(x["name_of_drug"], x["use_case_for_drug"], x["review_by_patient_filter"]), axis=1)
drug_train_data.head(2)
# Out:
#        patient_id name_of_drug use_case_for_drug  \
# 10091      223808  Depakote ER          Epilepsy
# 1009        35602      Anexsia              Pain
#
#                                        review_by_patient  \
# 10091  "After trying 4 different meds this one was th...
# 1009   "Worked better than Tylenol w/codeine #3 and C...
#
#        effectiveness_rating drug_approved_by_UIC  number_of_times_prescribed  \
# 10091                     8             1-Apr-08                          15
# 1009                     10             1-Apr-08                          19
#
#        base_score  review_len  review_n_words  \
# 10091    7.633384         370              74
# 1009     6.127475          88              14
#
#                                 review_by_patient_filter  \
# 10091  after trying 4 different meds this one was the...
# 1009   worked better than tylenol w codeine  3 and ca...
#
#                            review_by_patient_unique_word  \
# 10091  ['one', 'gladly', 'stayed', 'scary', 'well', '...
# 1009   ['w', 'tylenol', '3', 'better', 'pain', 'caris...
#
#        len_review_by_patient_unique_word  \
# 10091                                 35
# 1009                                  10
#
#                                  combine_name_use_review
# 10091  depakote er epilepsy after trying 4 different ...
# 1009   anexsia pain worked better than tylenol w code...

# %%
all_train_name_use_review = list(drug_train_data["combine_name_use_review"])

# %%
def create_vocabulary():       # no use
    vocabulary = set()
    [vocabulary.update(sent.split()) for sent in drug_train_data["combine_name_use_review"].values]
    return vocabulary
vocabulary = create_vocabulary()
print(f"vocabulary contains {len(vocabulary)} words")
# Out:
# vocabulary contains 28094 words

# %% [markdown]
# <h1>3 Create vocab of most frequent words </h1>

# %%
def create_vocab(word_count_threshold = 10):
    word_counts = {}
    nsents = 0
    for sent in all_train_name_use_review:
        nsents += 1
        for w in sent.split(' '):
            word_counts[w] = word_counts.get(w, 0) + 1
    c = 0
    for key, val in word_counts.items():
        if len(key) == 1:
            c += 1
            print(key)
    print(c)
    vocab = [w for w in word_counts if word_counts[w] >= word_count_threshold]
    return vocab, word_counts
vocab, word_counts = create_vocab(50)
print('Vocabulary = %d in our trainig data' % (len(vocab)))    # 10 -> 5607, 7-> 6705, 15-> 4477, 30->2985, 50 ->
# Out:
# 4
# i
# a
# w
# 3
# m
# 2
# 5
# p
# s
# t
# v
# 6
# 1
# 9
# e
# g
# 7
# b
# d
# 0
# 8
# l
# c
# u
# h
# x
# q
# n
# f
# o
# r
# z
# y
# k
# j
# _
# і
# 38
# Vocabulary = 3164 in our trainig data

# %%
def ixtoword_wordtoix():
    ixtoword = {}
    wordtoix = {}
    ix = 1
    for w in vocab:
        wordtoix[w] = ix
        ixtoword[ix] = w
        ix += 1
    return ixtoword, wordtoix
if 'wordtoix.pkl' in os.listdir("../ix_word"):
    print("load")
    ixtoword = load_pickle('../ix_word/ixtoword.pkl')
    wordtoix = load_pickle('../ix_word/wordtoix.pkl')
else:
    ixtoword, wordtoix = ixtoword_wordtoix()
    dump_pickle('../ix_word/ixtoword.pkl', ixtoword)
    dump_pickle('../ix_word/wordtoix.pkl', wordtoix)
    print("dump")
vocab_size = len(ixtoword) + 1
print('size of vocabulary = %d in our trainig data' % (vocab_size))
# Out:
# load
# size of vocabulary = 3167 in our trainig data

# %% [markdown]
# <h1>4 Maximum length of caption </h1>

# %%
max_length = max(len(d.split()) for d in all_train_name_use_review)
max_length
# Out:
# 650

# %% [markdown]
# <h1>5 Embadding index and matrix </h1>

# %%
def create_embadding_index():
    embeddings_index = {} 
    f = open(os.path.join(glove_path, 'glove.6B.200d.txt'), encoding="utf-8")
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    return embeddings_index
if "embeddings_index.pkl" in os.listdir("../ix_word"):
    print('load')
    embeddings_index = load_pickle(os.path.join("../ix_word", "embeddings_index.pkl"))
else:
    print("dump")
    embeddings_index = create_embadding_index()
    dump_pickle(os.path.join("../ix_word", "embeddings_index.pkl"), embeddings_index)

print(f"There are {len(embeddings_index)} no of words in glove")

# %%
def create_embadding_index():
    embeddings_index = {} 
    f = open(os.path.join(glove_path, 'glove.6B.200d.txt'), encoding="utf-8")
    for line in f:
        values = line.split()
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs
    return embeddings_index
if "embeddings_index.pickle" in os.listdir(r"D:\computer vision\image_caption"):
    print('load')
    embeddings_index = load_pickle(os.path.join(r"D:\computer vision\image_caption", "embeddings_index.pickle"))
else:
    print("dump")
    embeddings_index = create_embadding_index()
    dump_pickle(os.path.join("../ix_word", "embeddings_index.pkl"), embeddings_index)

print(f"There are {len(embeddings_index)} no of words in glove")
# Out:
# load
# There are 400000 no of words in glove

# %%
def create_embadding_matrix():
    embedding_dim = 200
    embedding_matrix = np.zeros((vocab_size, embedding_dim))
    for word, i in wordtoix.items():
        embedding_vector = embeddings_index.get(word)
        if embedding_vector is not None:
            embedding_matrix[i] = embedding_vector
        else:
            print(i, word)
    return embedding_matrix
if "embeddings_glove.pkl" in os.listdir("../ix_word"):
    print('load')
    embeddings_glove = load_pickle(os.path.join("../ix_word", "embeddings_glove.pkl"))
else:
    print("dump")
    embeddings_glove = create_embadding_matrix()
    dump_pickle(os.path.join("../ix_word", "embeddings_glove.pkl"), embeddings_glove)

print(f"The shape of glove representation is {embeddings_glove.shape}")
# Out:
# load
# The shape of glove representation is (3167, 200)

# %% [markdown]
# <h1>6 DistilBert Embedding </h1>

# %%
# Refer: https://huggingface.co/transformers/model_doc/distilbert.html#

from transformers import DistilBertTokenizer, TFDistilBertModel

distil_bert = 'distilbert-base-uncased' # Name of the pretrained models

#DistilBERT 
tokenizer = DistilBertTokenizer.from_pretrained(distil_bert)
model1 = TFDistilBertModel.from_pretrained(distil_bert)
# Out:
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertModel: ['vocab_transform', 'vocab_projector', 'activation_13', 'vocab_layer_norm']
# - This IS expected if you are initializing TFDistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFDistilBertModel were initialized from the model checkpoint at distilbert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.

# %%
def find_vec(sent):
    vec = tokenizer.encode(sent)
    vec = tf.constant(vec)[None, :]
    return model1(vec)[0][0, 0, :].numpy()

# distill_bert_embedding = np.zeros((len(all_train_name_use_review), 768))
def create_embadding_distil():
    global distill_bert_embedding
    embedding_dim = 768
    for i, sent in enumerate(all_train_name_use_review):
        embedding_vector = find_vec(sent[:2000])
        print(i, sent[0:20])
        if embedding_vector is not None:
            distill_bert_embedding[i] = embedding_vector
        else:
            print(i,"NNNNNNNNNNNNNNNNNNNN",  word)
    return distill_bert_embedding

# %%
if 'distill_bert_embedding.pkl' in os.listdir("../ix_word"):
    print("load")
    distill_bert_embedding = load_pickle('../ix_word/distill_bert_embedding.pkl')
else:
    distill_bert_embedding = create_embadding_distil()
    dump_pickle('../ix_word/distill_bert_embedding.pkl', distill_bert_embedding)
    print("dump")
# Out:
# load

# %%
distill_bert_embedding.shape
# Out:
# (32165, 768)

# %%
combine_name_use_review_df = pd.DataFrame(distill_bert_embedding, columns=[f"review_{i}" for i in range(768)])
combine_name_use_review_df.head(2)
# Out:
#    review_0  review_1  review_2  review_3  review_4  review_5  review_6  \
# 0  0.059691  0.008081  0.080178 -0.266999 -0.264136 -0.360968   0.64633
# 1 -0.477708 -0.197286 -0.113292 -0.019980 -0.573079 -0.220722   0.34921
#
#    review_7  review_8  review_9  ...  review_758  review_759  review_760  \
# 0  0.423532 -0.074173 -0.070809  ...   -0.140880   -0.184657    0.068444
# 1 -0.051921 -0.013572 -0.067297  ...    0.134501   -0.330719   -0.052216
#
#    review_761  review_762  review_763  review_764  review_765  review_766  \
# 0   -0.305117    0.219165   -0.065599   -0.351725   -0.171581    0.362696
# 1    0.190429    0.398500    0.230648   -0.213165   -0.396574    0.421274
#
#    review_767
# 0   -0.022024
# 1    0.357504
#
# [2 rows x 768 columns]

# %%
drug_train_data.head(2)
# Out:
#        patient_id name_of_drug use_case_for_drug  \
# 10091      223808  Depakote ER          Epilepsy
# 1009        35602      Anexsia              Pain
#
#                                        review_by_patient  \
# 10091  "After trying 4 different meds this one was th...
# 1009   "Worked better than Tylenol w/codeine #3 and C...
#
#        effectiveness_rating drug_approved_by_UIC  number_of_times_prescribed  \
# 10091                     8             1-Apr-08                          15
# 1009                     10             1-Apr-08                          19
#
#        base_score  review_len  review_n_words  \
# 10091    7.633384         370              74
# 1009     6.127475          88              14
#
#                                 review_by_patient_filter  \
# 10091  after trying 4 different meds this one was the...
# 1009   worked better than tylenol w codeine  3 and ca...
#
#                            review_by_patient_unique_word  \
# 10091  ['one', 'gladly', 'stayed', 'scary', 'well', '...
# 1009   ['w', 'tylenol', '3', 'better', 'pain', 'caris...
#
#        len_review_by_patient_unique_word  \
# 10091                                 35
# 1009                                  10
#
#                                  combine_name_use_review
# 10091  depakote er epilepsy after trying 4 different ...
# 1009   anexsia pain worked better than tylenol w code...

# %%
print("Number of features in preprocessed dataframe :", drug_train_data.shape[1])
print("Number of features in nlp dataframe :", combine_name_use_review_df.shape[1])
# Out:
# Number of features in preprocessed dataframe : 14
# Number of features in nlp dataframe : 768

# %% [markdown]
# <h1>7 Convert DataFrame to CSV File </h1>

# %%
# storing the final features to csv file
if not os.path.isfile('../ix_word/final_features.csv'):
    combine_name_use_review_df['patient_id']=drug_train_data['patient_id']
    combine_name_use_review_df['effectiveness_rating']=drug_train_data['effectiveness_rating']
    combine_name_use_review_df['drug_approved_by_UIC']=drug_train_data['drug_approved_by_UIC']
    combine_name_use_review_df['number_of_times_prescribed']=drug_train_data['number_of_times_prescribed']
    combine_name_use_review_df['len_review_by_patient_unique_word']=drug_train_data['len_review_by_patient_unique_word']
    combine_name_use_review_df['base_score']=drug_train_data['base_score']
    first_column = combine_name_use_review_df.pop('patient_id')
    combine_name_use_review_df.insert(0, 'patient_id', first_column)
    combine_name_use_review_df.to_csv('../ix_word/final_features.csv')

# %%
combine_name_use_review_df.head(2)
# Out:
#    review_0  review_1  review_2  review_3  review_4  review_5  review_6  \
# 0  0.059691  0.008081  0.080178 -0.266999 -0.264136 -0.360968   0.64633
# 1 -0.477708 -0.197286 -0.113292 -0.019980 -0.573079 -0.220722   0.34921
#
#    review_7  review_8  review_9  ...  review_758  review_759  review_760  \
# 0  0.423532 -0.074173 -0.070809  ...   -0.140880   -0.184657    0.068444
# 1 -0.051921 -0.013572 -0.067297  ...    0.134501   -0.330719   -0.052216
#
#    review_761  review_762  review_763  review_764  review_765  review_766  \
# 0   -0.305117    0.219165   -0.065599   -0.351725   -0.171581    0.362696
# 1    0.190429    0.398500    0.230648   -0.213165   -0.396574    0.421274
#
#    review_767
# 0   -0.022024
# 1    0.357504
#
# [2 rows x 768 columns]

# %%
combine_name_use_review_df.shape
# Out:
# (32165, 768)

# %% [markdown]
# <h1>8 Test Data</h1>

# %%
drug_test_data = pd.read_csv("drug_test_preprocess.csv", index_col="Unnamed: 0")
drug_test_data.head(2)
# Out:
#    patient_id name_of_drug                                  review_by_patient  \
# 0      163740  Mirtazapine  "I&#039;ve tried a few antidepressants over th...
# 1       39293     Contrave  "Contrave combines drugs that were used for al...
#
#   drug_approved_by_UIC  number_of_times_prescribed use_case_for_drug  \
# 0            28-Feb-12                          22        Depression
# 1             5-Mar-17                          35       Weight Loss
#
#    effectiveness_rating                           review_by_patient_filter  \
# 0                    10  i  039 ve tried a few antidepressants over the...
# 1                     9  contrave combines drugs that were used for alc...
#
#                        review_by_patient_unique_word  \
# 0  ['insomnia', 'changed', 'tried', 'actually', '...
# 1  ['work', 'want', 'contrave', 'know', 'obesity'...
#
#    len_review_by_patient_unique_word  review_len  review_n_words
# 0                                 36         439              68
# 1                                 62         782             143

# %%
drug_test_data["combine_name_use_review"] = drug_test_data.loc[:, ["name_of_drug", "use_case_for_drug", "review_by_patient_filter"]].fillna("").apply(lambda x: combine_name_use_review(x["name_of_drug"], x["use_case_for_drug"], x["review_by_patient_filter"]), axis=1)
drug_test_data.head(2)
# Out:
#    patient_id name_of_drug                                  review_by_patient  \
# 0      163740  Mirtazapine  "I&#039;ve tried a few antidepressants over th...
# 1       39293     Contrave  "Contrave combines drugs that were used for al...
#
#   drug_approved_by_UIC  number_of_times_prescribed use_case_for_drug  \
# 0            28-Feb-12                          22        Depression
# 1             5-Mar-17                          35       Weight Loss
#
#    effectiveness_rating                           review_by_patient_filter  \
# 0                    10  i  039 ve tried a few antidepressants over the...
# 1                     9  contrave combines drugs that were used for alc...
#
#                        review_by_patient_unique_word  \
# 0  ['insomnia', 'changed', 'tried', 'actually', '...
# 1  ['work', 'want', 'contrave', 'know', 'obesity'...
#
#    len_review_by_patient_unique_word  review_len  review_n_words  \
# 0                                 36         439              68
# 1                                 62         782             143
#
#                              combine_name_use_review
# 0  mirtazapine depression i  039 ve tried a few a...
# 1  contrave weight loss contrave combines drugs t...

# %%
all_test_name_use_review = list(drug_test_data["combine_name_use_review"])
len(all_test_name_use_review)
# Out:
# 10760

# %%
def find_vec(sent):
    vec = tokenizer.encode(sent)
    vec = tf.constant(vec)[None, :]
    return model1(vec)[0][0, 0, :].numpy()

distill_bert_embedding_test = np.zeros((len(all_test_name_use_review), 768))
def create_embadding_distil():
    global distill_bert_embedding_test
    embedding_dim = 768
    for i, sent in enumerate(all_test_name_use_review):
        embedding_vector = find_vec(sent[:2000])
        print(i, sent[0:20])
        if embedding_vector is not None:
            distill_bert_embedding[i] = embedding_vector
        else:
            print(i,"NNNNNNNNNNNNNNNNNNNN",  word)
    return distill_bert_embedding

# %%
if 'distill_bert_embedding_test.pkl' in os.listdir("../ix_word"):
    print("load")
    distill_bert_embedding_test = load_pickle('../ix_word/distill_bert_embedding_test.pkl')
else:
    distill_bert_embedding_test = create_embadding_distil()
    dump_pickle('../ix_word/distill_bert_embedding_test.pkl', distill_bert_embedding_test)
    print("dump")
# Out:
# 0 mirtazapine depressi
# 1 contrave weight loss
# 2 zyclara keratosis 4
# 3 methadone opiate wit
# 4 ambien insomnia ditt
# 5 nuvigil narcolepsy a
# 6 blisovi fe 1   20 bi
# 7 ivermectin rosacea i
# 8 nuvaring birth contr
# 9 escitalopram depress
# 10 gabapentin bipolar d
# 11 aubra birth control
# 12 ethinyl estradiol
# 13 miconazole vaginal y
# 14 nitrofurantoin bladd
# 15 tamsulosin benign pr
# 16 cryselle endometrios
# 17 pramipexole restless
# 18 nifedipine raynaud o
# 19 sertraline major dep
# 20 phentermine obesity
# 21 campral alcohol depe
# 22 buspar anxiety i did
# 23 promethazine nausea
# 24 tioconazole vaginal
# 25 levonorgestrel birth
# 26 nicoderm cq smoking
# 27 fluoxetine major dep
# 28 depakote bipolar dis
# 29 lo loestrin fe birth
# 30 phentermine weight l
# 31 amitriptyline ibromy
# 32 beyaz acne i have be
# 33 levonorgestrel emerg
# 34 zoloft social anxiet
# 35 desvenlafaxine depre
# 36 pristiq major depres
# 37 depo provera birth c
# 38 sovaldi hepatitis c
# 39 valacyclovir cold so
# 40 quetiapine bipolar d
# 41 estradiol postmenopa
# 42 gabapentin ibromyalg
# 43 vilazodone depressio
# 44 bupropion depression
# 45 miralax constipation
# 46 levonorgestrel birth
# 47 imiquimod human papi
# 48 implanon birth contr
# 49 restasis keratoconju
# 50 zoloft depression de
# 51 gleevec chronic myel
# 52 nexplanon birth cont
# 53 depo provera endomet
# 54 clomiphene emale inf
# 55 gabapentin anxiety i
# 56 vitamin d2 vitamin d
# 57 lysteda menstrual di
# 58 ethinyl estradiol
# 59 zoloft depression i
# 60 diphenhydramine inso
# 61 pazopanib soft tissu
# 62 bisacodyl constipati
# 63 paxil anxiety i star
# 64 adipex p weight loss
# 65 implanon birth contr
# 66 niravam anxiety i ha
# 67 cefuroxime sinusitis
# 68 alesse birth control
# 69 tretinoin acne treti
# 70 nexplanon birth cont
# 71 aspirin   carisoprod
# 72 canagliflozin diabet
# 73 vyvanse adhd i had m
# 74 junel fe 1   20 birt
# 75 pegfilgrastim neutro
# 76 lisinopril high bloo
# 77 junel fe 1   20 mens
# 78 miconazole vaginal y
# 79 meclizine vertig i h
# 80 junel fe 1 5   30 bi
# 81 pravastatin high cho
# 82 amitriptyline anxiet
# 83 clonazepam restless
# 84 amitriptyline ibromy
# 85 contrave weight loss
# 86 contrave obesity bee
# 87 junel fe 1   20 acne
# 88 lo loestrin fe birth
# 89 phentermine weight l
# 90 topamax migraine pre
# 91 chateal birth contro
# 92 cyclobenzaprine musc
# 93 uptravi pulmonary hy
# 94 topiramate seizure p
# 95 orphenadrine muscle
# 96 tadalafil erectile d
# 97 humira rheumatoid ar
# 98 suprep bowel prep ki
# 99 levonorgestrel emerg
# 100 etonogestrel birth c
# 101 sronyx abnormal uter
# 102 paxil anxiety i was
# 103 ortho tri cyclen lo
# 104 linaclotide constipa
# 105 medroxyprogesterone
# 106 perampanel epilepsy
# 107 acetaminophen   dexb
# 108 avinza pain so much
# 109 cialis 9  span  user
# 110 ethinyl estradiol
# 111 saphris bipolar diso
# 112 phillips  milk of ma
# 113 citalopram depressio
# 114 terbinafine onychomy
# 115 wellbutrin depressio
# 116 mesalamine ulcerativ
# 117 plan b emergency con
# 118 norco back pain so f
# 119 phentermine   topira
# 120 sertraline depressio
# 121 buprenorphine   nalo
# 122 ortho cyclen birth c
# 123 advair hfa asthma  m
# 124 seroquel bipolar dis
# 125 adapalene   benzoyl
# 126 ethinyl estradiol
# 127 toradol postoperativ
# 128 aluminum chloride he
# 129 gabapentin periphera
# 130 dexmethylphenidate a
# 131 nuvaring birth contr
# 132 sertraline major dep
# 133 cyclobenzaprine ibro
# 134 lansoprazole gerd th
# 135 hydrocodone not list
# 136 ethinyl estradiol
# 137 azor high blood pres
# 138 nitrofurantoin urina
# 139 indomethacin gout  a
# 140 wellbutrin xl major
# 141 ziprasidone schizoaf
# 142 levofloxacin skin or
# 143 ethinyl estradiol
# 144 tri sprintec 10  spa
# 145 methylphenidate narc
# 146 mirena birth control
# 147 terbinafine onychomy
# 148 amerge migraine i ha
# 149 levonorgestrel birth
# 150 sprintec birth contr
# 151 avonex pen multiple
# 152 azithromycin chlamyd
# 153 paxil generalized an
# 154 cambia migraine i ha
# 155 tizanidine muscle sp
# 156 exalgo chronic pain
# 157 nuvigil hypersomnia
# 158 belviq obesity i had
# 159 venlafaxine depressi
# 160 lurasidone bipolar d
# 161 wellbutrin depressio
# 162 amlodipine high bloo
# 163 minastrin 24 fe birt
# 164 donnatal duodenal ul
# 165 trinessa birth contr
# 166 aluminum chloride he
# 167 levofloxacin sinusit
# 168 nexplanon birth cont
# 169 dulera asthma  maint
# 170 portia birth control
# 171 hydroxyzine anxiety
# 172 prozac anxiety and s
# 173 lorcaserin weight lo
# 174 propafenone atrial f
# 175 acetaminophen   hydr
# 176 oxycodone chronic pa
# 177 trimethoprim urinary
# 178 bupropion depression
# 179 onabotulinumtoxina o
# 180 dulaglutide diabetes
# 181 omeprazole barrett o
# 182 finasteride androgen
# 183 synthroid hypothyroi
# 184 differin acne i bega
# 185 buprenorphine   nalo
# 186 doxepin depression t
# 187 yasmin birth control
# 188 macrodantin preventi
# 189 phentermine weight l
# 190 suprep bowel prep ki
# 191 risperidone depressi
# 192 sulfamethoxazole   t
# 193 bupropion depression
# 194 keppra xr epilepsy i
# 195 ledipasvir   sofosbu
# 196 skyla birth control
# 197 phentermine obesity
# 198 copaxone multiple sc
# 199 magnesium sulfate
# 200 ethinyl estradiol
# 201 aubra birth control
# 202 tylenol pain i was p
# 203 ethinyl estradiol
# 204 luvox depression luv
# 205 hydroxyzine anxiety
# 206 carvedilol heart fai
# 207 tretinoin acne i tri
# 208 doxycycline chlamydi
# 209 drysol 0  span  user
# 210 implanon birth contr
# 211 liothyronine underac
# 212 propranolol pe aweso
# 213 levonorgestrel emerg
# 214 ethinyl estradiol
# 215 skyla birth control
# 216 lorcaserin obesity i
# 217 levonorgestrel emerg
# 218 levonorgestrel abnor
# 219 lutera birth control
# 220 topamax bipolar diso
# 221 valium muscle spasm
# 222 alprazolam anxiety i
# 223 qsymia weight loss i
# 224 duloxetine depressio
# 225 duloxetine ibromyalg
# 226 levonorgestrel birth
# 227 etanercept rheumatoi
# 228 vortioxetine depress
# 229 naproxen back pain r
# 230 fentanyl transdermal
# 231 zipsor pain i take z
# 232 melatonin not listed
# 233 tioconazole vaginal
# 234 tioconazole vaginal
# 235 prazosin nightmares
# 236 ethinyl estradiol
# 237 orlistat obesity jus
# 238 atomoxetine adhd my
# 239 bronkaid cold sympto
# 240 ethinyl estradiol
# 241 kariva birth control
# 242 gabapentin diabetic
# 243 ambien insomnia due
# 244 sronyx birth control
# 245 metoclopramide migra
# 246 tri sprintec birth c
# 247 leuprolide endometri
# 248 belviq obesity i hav
# 249 tretinoin acne retin
# 250 magnesium citrate co
# 251 metronidazole bacter
# 252 methadone pain been
# 253 citalopram depressio
# 254 cefdinir sinusitis d
# 255 methadone pain metha
# 256 metaxalone muscle sp
# 257 vilazodone major dep
# 258 magnesium sulfate
# 259 magnesium sulfate
# 260 prednisone pharyngit
# 261 fluoxetine depressio
# 262 nexplanon birth cont
# 263 etonogestrel birth c
# 264 bupropion   naltrexo
# 265 amitriptyline migrai
# 266 ethinyl estradiol
# 267 acetaminophen   hydr
# 268 phentermine weight l
# 269 drospirenone   ethin
# 270 nucynta er pain i ha
# 271 citric acid   magnes
# 272 ethinyl estradiol
# 273 ethinyl estradiol
# 274 levonorgestrel emerg
# 275 divalproex sodium bi
# 276 skyla birth control
# 277 zovirax cream cold s
# 278 cobicistat   elviteg
# 279 ethinyl estradiol
# 280 saxenda obesity been
# 281 pregabalin ibromyalg
# 282 lisdexamfetamine adh
# 283 wellbutrin depressio
# 284 cetirizine allergic
# 285 ethinyl estradiol
# 286 azithromycin otitis
# 287 armodafinil bipolar
# 288 ranolazine angina pr
# 289 bupropion   naltrexo
# 290 fluoxetine depressio
# 291 trinessa birth contr
# 292 metoclopramide migra
# 293 gildess fe 1   20 bi
# 294 eflornithine hirsuti
# 295 quetiapine borderlin
# 296 magnesium sulfate
# 297 mirtazapine post tra
# 298 rizatriptan migraine
# 299 ethinyl estradiol
# 300 librax irritable bow
# 301 sildenafil sexual dy
# 302 pradaxa prevention o
# 303 kava anxiety kava is
# 304 oxymorphone pain i s
# 305 liraglutide weight l
# 306 flonase rhinitis omg
# 307 stendra erectile dys
# 308 zoloft major depress
# 309 ondansetron nausea v
# 310 avinza pain i have b
# 311 duloxetine back pain
# 312 implanon birth contr
# 313 phentermine weight l
# 314 copper birth control
# 315 bupropion   naltrexo
# 316 vraylar schizophreni
# 317 acetaminophen   dich
# 318 venlafaxine postpart
# 319 epiduo acne this sum
# 320 sulfamethoxazole   t
# 321 oseltamivir influenz
# 322 desvenlafaxine depre
# 323 blisovi fe 1   20 bi
# 324 bupropion   naltrexo
# 325 junel fe 1   20 birt
# 326 nuvaring birth contr
# 327 ethinyl estradiol
# 328 etonogestrel birth c
# 329 metronidazole divert
# 330 seroquel bipolar dis
# 331 drospirenone   ethin
# 332 halcion insomnia i w
# 333 suboxone opiate depe
# 334 invokana diabetes  t
# 335 risperidone paranoid
# 336 levonorgestrel birth
# 337 trintellix depressio
# 338 etonogestrel birth c
# 339 natalizumab multiple
# 340 tylenol with codeine
# 341 prozac anxiety and s
# 342 acetaminophen   hydr
# 343 prednisone sinusitis
# 344 venlafaxine depressi
# 345 azithromycin chlamyd
# 346 magnesium sulfate
# 347 azelastine allergic
# 348 duloxetine depressio
# 349 efinaconazole onycho
# 350 pradaxa prevention o
# 351 etonogestrel birth c
# 352 sanctura overactive
# 353 lorazepam anxiety af
# 354 benadryl allergy urt
# 355 trintellix depressio
# 356 phentermine weight l
# 357 lutera birth control
# 358 phentermine weight l
# 359 ambien insomnia i  0
# 360 trintellix major dep
# 361 venlafaxine anxiety
# 362 ocella birth control
# 363 etonogestrel birth c
# 364 lasix edema have onl
# 365 amoxicillin   clavul
# 366 saxenda obesity i st
# 367 microgestin fe 1   2
# 368 viibryd depression t
# 369 wellbutrin depressio
# 370 suprep bowel prep ki
# 371 fluorouracil actinic
# 372 savella ibromyalgia
# 373 varenicline smoking
# 374 farxiga diabetes  ty
# 375 sertraline depressio
# 376 phentermine   topira
# 377 ondansetron nausea v
# 378 alprazolam anxiety s
# 379 kenalog 40 allergic
# 380 bactrim urinary trac
# 381 ethinyl estradiol
# 382 zoloft postpartum de
# 383 naproxen   sumatript
# 384 clonazepam bipolar d
# 385 testosterone hypogon
# 386 promethazine allergi
# 387 tretinoin acne this
# 388 azathioprine ulcerat
# 389 etonogestrel birth c
# 390 tamiflu influenza my
# 391 zolpidem insomnia it
# 392 cymbalta major depre
# 393 mirabegron overactiv
# 394 butrans chronic pain
# 395 adipex p weight loss
# 396 fioricet headache i
# 397 ortho tri cyclen lo
# 398 ethinyl estradiol
# 399 sulfacetamide sodium
# 400 kyleena birth contro
# 401 ethinyl estradiol
# 402 portia birth control
# 403 vortioxetine major d
# 404 loestrin 24 fe birth
# 405 clopidogrel platelet
# 406 canagliflozin diabet
# 407 atropine   hyoscyami
# 408 implanon birth contr
# 409 escitalopram anxiety
# 410 rituximab wegener ow
# 411 saxenda weight loss
# 412 amphetamine adhd eh
# 413 bupropion   naltrexo
# 414 desvenlafaxine major
# 415 bupropion depression
# 416 melatonin insomnia i
# 417 buprenorphine opiate
# 418 ambien insomnia i  0
# 419 opana pain opana is
# 420 seroquel xr depressi
# 421 fesoterodine overact
# 422 benzoic acid   salic
# 423 levaquin kidney infe
# 424 desvenlafaxine panic
# 425 mirtazapine depressi
# 426 trintellix major dep
# 427 excedrin back   body
# 428 levonorgestrel birth
# 429 polyethylene glycol
# 430 femara breast cance
# 431 savella ibromyalgia
# 432 linaclotide constipa
# 433 oxycontin pain oxyco
# 434 tioconazole vaginal
# 435 minocycline rosacea
# 436 loseasonique endomet
# 437 nexplanon birth cont
# 438 etonogestrel birth c
# 439 lamotrigine bipolar
# 440 oxymorphone pain opa
# 441 etonogestrel birth c
# 442 celebrex juvenile rh
# 443 desvenlafaxine depre
# 444 senna constipation o
# 445 bupropion depression
# 446 dulcolax constipatio
# 447 synthroid hypothyroi
# 448 mirena birth control
# 449 qsymia weight loss i
# 450 azithromycin chlamyd
# 451 lexapro generalized
# 452 sprintec abnormal ut
# 453 etonogestrel birth c
# 454 buprenorphine chroni
# 455 cymbalta ibromyalgia
# 456 tazorac acne my derm
# 457 lomotil diarrhea thi
# 458 sildenafil erectile
# 459 cymbalta diabetic pe
# 460 loestrin 21 1   20 a
# 461 linzess constipation
# 462 elmiron interstitial
# 463 lithium bipolar diso
# 464 ethinyl estradiol
# 465 remicade crohn own d
# 466 asenapine schizoaffe
# 467 etonogestrel birth c
# 468 risperidone bipolar
# 469 asenapine bipolar di
# 470 tacrolimus organ tra
# 471 celexa depression i
# 472 ustekinumab psoriati
# 473 nuvaring birth contr
# 474 xerac ac hyperhidros
# 475 flurazepam insomnia
# 476 maxalt mlt migraine
# 477 fluticasone   salmet
# 478 lipitor high cholest
# 479 lo loestrin fe birth
# 480 nebivolol high blood
# 481 simvastatin high cho
# 482 vraylar bipolar diso
# 483 tradjenta diabetes
# 484 colchicine gout  acu
# 485 xiidra dry eye disea
# 486 macrobid urinary tra
# 487 etonogestrel birth c
# 488 botox overactive bla
# 489 sulfamethoxazole   t
# 490 nuvaring birth contr
# 491 buspirone anxiety i
# 492 meclizine vertig jus
# 493 paroxetine depressio
# 494 sucralfate stomach u
# 495 amoxicillin   clavul
# 496 toradol pain i have
# 497 hypercare hyperhidro
# 498 citalopram depressio
# 499 copper birth control
# 500 nuvaring birth contr
# 501 sertraline anxiety a
# 502 claravis acne this m
# 503 sertraline depressio
# 504 microgestin fe 1   2
# 505 suprep bowel prep ki
# 506 avanafil erectile dy
# 507 plan b emergency con
# 508 metformin diabetes
# 509 spironolactone acne
# 510 testosterone hypogon
# 511 tamsulosin urinary t
# 512 hiprex urinary tract
# 513 methadone chronic pa
# 514 chlordiazepoxide alc
# 515 seroquel bipolar dis
# 516 opana er pain i just
# 517 vyvanse adhd i  039
# 518 polyethylene glycol
# 519 yaz birth control so
# 520 ambien cr insomnia i
# 521 leuprolide prostate
# 522 nexplanon birth cont
# 523 pregabalin restless
# 524 keflex bacterial inf
# 525 dymista allergic rhi
# 526 ethinyl estradiol
# 527 saphris bipolar diso
# 528 contrave weight loss
# 529 fluvoxamine obsessiv
# 530 ortho tri cyclen lo
# 531 ethinyl estradiol
# 532 moxifloxacin bronchi
# 533 lexapro anxiety i po
# 534 etonogestrel birth c
# 535 lo loestrin fe birth
# 536 vesicare overactive
# 537 triumeq hiv infectio
# 538 percocet pain i take
# 539 drospirenone   ethin
# 540 suprep bowel prep ki
# 541 amitriptyline migrai
# 542 yaz premenstrual dys
# 543 dextroamphetamine ad
# 544 pylera helicobacter
# 545 cabergoline hyperpro
# 546 hydrochlorothiazide
# 547 liraglutide diabetes
# 548 homatropine   hydroc
# 549 vortioxetine depress
# 550 metronidazole bacter
# 551 ethinyl estradiol
# 552 invokana diabetes  t
# 553 wellbutrin sr depres
# 554 contrave obesity lov
# 555 avodart benign prost
# 556 skyla birth control
# 557 olanzapine schizophr
# 558 yaz menstrual disord
# 559 yuvafem atrophic vag
# 560 lo loestrin fe birth
# 561 testosterone hypogon
# 562 nexplanon birth cont
# 563 ciprofloxacin prosta
# 564 levonorgestrel birth
# 565 medroxyprogesterone
# 566 fluoxetine premenstr
# 567 viberzi irritable bo
# 568 ethinyl estradiol
# 569 cyproheptadine anore
# 570 advil pain i love th
# 571 phentermine weight l
# 572 baclofen muscle spas
# 573 synvisc one osteoart
# 574 cymbalta anxiety i r
# 575 baclofen alcohol wit
# 576 suprep bowel prep ki
# 577 levonorgestrel birth
# 578 sutent renal cell ca
# 579 propranolol mance an
# 580 femhrt menstrual dis
# 581 augmentin upper resp
# 582 provera abnormal ute
# 583 adderall adhd i have
# 584 acamprosate alcohol
# 585 oxycodone pain it wo
# 586 pristiq depression i
# 587 benazepril high bloo
# 588 wellbutrin depressio
# 589 effexor depression b
# 590 risperdal schizophre
# 591 isotretinoin acne i
# 592 ethinyl estradiol
# 593 vyvanse adhd i am 18
# 594 skyla birth control
# 595 frova migraine i  03
# 596 ethinyl estradiol
# 597 paroxetine anxiety a
# 598 xarelto atrial fibri
# 599 azelaic acid rosacea
# 600 venlafaxine depressi
# 601 eliquis prevention o
# 602 mirtazapine depressi
# 603 senna constipation o
# 604 ketorolac pain was e
# 605 plan b emergency con
# 606 sulfamethoxazole   t
# 607 copper birth control
# 608 paroxetine anxiety p
# 609 reglan nausea vomiti
# 610 topiramate migraine
# 611 nortriptyline pain i
# 612 pregabalin ibromyalg
# 613 venlafaxine depressi
# 614 ethinyl estradiol
# 615 etonogestrel birth c
# 616 bactrim acne i  039
# 617 fluoxetine depressio
# 618 bisacodyl constipati
# 619 contrave obesity i s
# 620 varenicline smoking
# 621 trinessa ovarian cys
# 622 keppra seizures i ha
# 623 seasonique abnormal
# 624 oxcarbazepine bipola
# 625 necon 1   35 polycys
# 626 fiorinal pain i have
# 627 medroxyprogesterone
# 628 clonidine opiate wit
# 629 seroquel insomnia i
# 630 paroxetine panic dis
# 631 fluticasone allergic
# 632 isotretinoin acne i
# 633 phentermine   topira
# 634 azelaic acid rosacea
# 635 phentermine weight l
# 636 sprintec birth contr
# 637 ethinyl estradiol
# 638 lexapro depression i
# 639 ethinyl estradiol
# 640 milnacipran ibromyal
# 641 fentanyl chronic pai
# 642 nexplanon birth cont
# 643 abilify obsessive co
# 644 vilazodone anxiety t
# 645 nubain pain i  039 v
# 646 lutera birth control
# 647 skelaxin muscle spas
# 648 amitriptyline pain i
# 649 ethinyl estradiol
# 650 clarithromycin upper
# 651 demerol pain this me
# 652 venlafaxine social a
# 653 qsymia weight loss i
# 654 ziprasidone schizoaf
# 655 percocet pain i had
# 656 levonorgestrel emerg
# 657 ranibizumab macular
# 658 belbuca chronic pain
# 659 zubsolv opiate depen
# 660 oseltamivir swine fl
# 661 ultram er pain this
# 662 advair diskus asthma
# 663 lorcaserin weight lo
# 664 jalyn benign prostat
# 665 linzess constipation
# 666 doxycycline rosacea
# 667 methotrexate rheumat
# 668 acetaminophen   buta
# 669 lurasidone bipolar d
# 670 cenestin postmenopau
# 671 letrozole breast can
# 672 sprintec birth contr
# 673 tamsulosin benign pr
# 674 duloxetine anxiety s
# 675 desogestrel   ethiny
# 676 lortab pain lortab i
# 677 chantix smoking cess
# 678 amitriptyline migrai
# 679 levonorgestrel birth
# 680 sulfasalazine ulcera
# 681 ethinyl estradiol
# 682 levonorgestrel birth
# 683 fluticasone   salmet
# 684 dextroamphetamine ad
# 685 alesse abnormal uter
# 686 copper birth control
# 687 levofloxacin sinusit
# 688 tramadol back pain s
# 689 atorvastatin high ch
# 690 vyvanse adhd diagnos
# 691 strattera adhd worke
# 692 ortho micronor birth
# 693 levonorgestrel birth
# 694 ethinyl estradiol
# 695 venlafaxine panic di
# 696 wellbutrin depressio
# 697 dapsone acne i  039
# 698 desvenlafaxine depre
# 699 oxytrol overactive b
# 700 metronidazole bacter
# 701 elavil pain i use el
# 702 alprazolam panic dis
# 703 nuvaring birth contr
# 704 suboxone opiate depe
# 705 levonorgestrel emerg
# 706 cephalexin upper res
# 707 amitiza constipation
# 708 atorvastatin high ch
# 709 propranolol migraine
# 710 etonogestrel birth c
# 711 zoloft post traumati
# 712 micardis high blood
# 713 zithromax sinusitis
# 714 amoxicillin   clavul
# 715 tri previfem birth c
# 716 toradol iv   im pain
# 717 citalopram depressio
# 718 paliperidone schizop
# 719 meloxicam osteoarthr
# 720 mirtazapine insomnia
# 721 hydromorphone chroni
# 722 ethinyl estradiol
# 723 nitrofurantoin urina
# 724 oxycodone pain my do
# 725 sprintec birth contr
# 726 temazepam insomnia t
# 727 etanercept rheumatoi
# 728 ziana acne i  039 m
# 729 strattera adhd takin
# 730 chlordiazepoxide alc
# 731 isotretinoin acne i
# 732 levetiracetam epilep
# 733 triazolam insomnia a
# 734 nifedipine high bloo
# 735 tamoxifen breast can
# 736 cyproheptadine migra
# 737 apremilast plaque ps
# 738 botox cervical dysto
# 739 ibuprofen period pai
# 740 insulin glargine dia
# 741 miconazole vaginal y
# 742 implanon birth contr
# 743 azithromycin chlamyd
# 744 belviq obesity fanta
# 745 pregabalin neuropath
# 746 tri sprintec birth c
# 747 lunesta insomnia i h
# 748 suprep bowel prep ki
# 749 tioconazole vaginal
# 750 tadalafil erectile d
# 751 victoza diabetes  ty
# 752 suboxone opiate depe
# 753 actemra rheumatoid a
# 754 mirena birth control
# 755 etonogestrel birth c
# 756 levonorgestrel birth
# 757 azithromycin chlamyd
# 758 ethinyl estradiol
# 759 ultram pain had surg
# 760 nitrofurantoin urina
# 761 silenor insomnia my
# 762 prednisone ulcerativ
# 763 ethinyl estradiol
# 764 lorcaserin weight lo
# 765 docosanol herpes sim
# 766 diclofenac ankylosin
# 767 lisinopril high bloo
# 768 monistat 3 day combi
# 769 aripiprazole major d
# 770 aspirin   butalbital
# 771 sprintec birth contr
# 772 magnesium sulfate
# 773 belviq weight loss a
# 774 alprazolam anxiety v
# 775 ropinirole restless
# 776 nexplanon birth cont
# 777 nitrofurantoin bladd
# 778 nitrofurantoin urina
# 779 intuniv adhd my son
# 780 ethinyl estradiol
# 781 cefdinir sinusitis f
# 782 tioconazole vaginal
# 783 plan b one step emer
# 784 opium diarrhea from
# 785 suprep bowel prep ki
# 786 amaryl diabetes  typ
# 787 solu medrol inflamma
# 788 ethinyl estradiol
# 789 drysol hyperhidrosis
# 790 gabapentin neuropath
# 791 zubsolv opiate depen
# 792 zoloft panic disorde
# 793 paxil anxiety well
# 794 docosanol herpes sim
# 795 linzess constipation
# 796 geodon schizoaffecti
# 797 sertraline post trau
# 798 benzoyl peroxide   c
# 799 gabapentin hot flash
# 800 lysteda menstrual di
# 801 restoril insomnia i
# 802 sulfamethoxazole   t
# 803 valacyclovir cold so
# 804 nexplanon birth cont
# 805 amlodipine   olmesar
# 806 lubiprostone irritab
# 807 perphenazine bipolar
# 808 eszopiclone insomnia
# 809 avonex multiple scle
# 810 geodon autism my dau
# 811 dulcolax constipatio
# 812 esgic headache one e
# 813 xarelto deep vein th
# 814 lunesta insomnia i t
# 815 levonorgestrel birth
# 816 accutane acne accuta
# 817 lorazepam intensol p
# 818 kyleena birth contro
# 819 mirena birth control
# 820 amitriptyline migrai
# 821 clonazepam insomnia
# 822 pazopanib renal cell
# 823 junel fe 1   20 abno
# 824 st  john own wort de
# 825 mirena birth control
# 826 thyroid desiccated u
# 827 levonorgestrel birth
# 828 paliperidone schizop
# 829 contrave obesity on
# 830 tegretol bipolar dis
# 831 olanzapine bipolar d
# 832 meridia obesity i st
# 833 paxil social anxiety
# 834 ethinyl estradiol
# 835 ethinyl estradiol
# 836 zoloft depression i
# 837 brexpiprazole not li
# 838 mirtazapine anxiety
# 839 doxycycline acne thi
# 840 chateal birth contro
# 841 vesicare overactive
# 842 doxycycline acne i
# 843 lupron depot endomet
# 844 ranitidine gastric u
# 845 amoxicillin   clavul
# 846 zolpidem insomnia it
# 847 advair diskus asthma
# 848 lo loestrin fe birth
# 849 prednisone inflammat
# 850 quetiapine bipolar d
# 851 mirena birth control
# 852 coreg left ventricul
# 853 anastrozole breast c
# 854 azithromycin otitis
# 855 ethinyl estradiol
# 856 fluoxetine panic dis
# 857 suprep bowel prep ki
# 858 daytrana adhd my son
# 859 bystolic high blood
# 860 adapalene   benzoyl
# 861 tamsulosin benign pr
# 862 lurasidone bipolar d
# 863 oxymetazoline nasal
# 864 cipro urinary tract
# 865 levonorgestrel birth
# 866 lifitegrast dry eye
# 867 guanfacine adhd my 1
# 868 medroxyprogesterone
# 869 tamiflu influenza se
# 870 risperdal bipolar di
# 871 milk of magnesia con
# 872 zovia birth control
# 873 contrave obesity sta
# 874 dexlansoprazole gerd
# 875 escitalopram depress
# 876 contrave weight loss
# 877 ethinyl estradiol
# 878 quetiapine bipolar d
# 879 chlorzoxazone muscle
# 880 modafinil narcolepsy
# 881 plan b one step emer
# 882 paxil generalized an
# 883 escitalopram general
# 884 citalopram depressio
# 885 sulfamethoxazole   t
# 886 percodan 4  span  us
# 887 lamisil onychomycosi
# 888 polyethylene glycol
# 889 citalopram depressio
# 890 allopurinol gout had
# 891 cyclobenzaprine musc
# 892 oxybutynin overactiv
# 893 guaifenesin   pseudo
# 894 dicyclomine irritabl
# 895 nitrofurantoin bladd
# 896 valtrex herpes simpl
# 897 lorazepam anxiety i
# 898 belviq obesity belvi
# 899 mucinex d maximum st
# 900 lisdexamfetamine adh
# 901 levonorgestrel birth
# 902 tri lo estarylla bir
# 903 etonogestrel birth c
# 904 linaclotide irritabl
# 905 duloxetine depressio
# 906 diclofenac osteoarth
# 907 phentermine weight l
# 908 loestrin 24 fe abnor
# 909 paliperidone schizop
# 910 ortho evra birth con
# 911 chondroitin   glucos
# 912 paroxetine anxiety i
# 913 edarbyclor high bloo
# 914 azithromycin chlamyd
# 915 stribild hiv infecti
# 916 effexor major depres
# 917 benzonatate cough no
# 918 liraglutide weight l
# 919 levonorgestrel emerg
# 920 ethinyl estradiol
# 921 flurazepam insomnia
# 922 effexor depression i
# 923 flonase allergic rhi
# 924 phentermine   topira
# 925 venlafaxine depressi
# 926 ella emergency contr
# 927 metronidazole crohn
# 928 remicade rheumatoid
# 929 ativan anxiety given
# 930 ethinyl estradiol
# 931 duloxetine anxiety i
# 932 cobicistat   elviteg
# 933 diclofenac period pa
# 934 tussionex pennkineti
# 935 kyleena birth contro
# 936 aczone acne i am a 4
# 937 levonorgestrel birth
# 938 medroxyprogesterone
# 939 amphetamine   dextro
# 940 exforge high blood p
# 941 enbrel psoriatic art
# 942 eszopiclone insomnia
# 943 dapagliflozin diabet
# 944 clonazepam anxiety a
# 945 ciprofloxacin kidney
# 946 acetaminophen   oxyc
# 947 ambien insomnia i  0
# 948 benzoyl peroxide   c
# 949 cialis erectile dysf
# 950 wellbutrin anxiety h
# 951 keppra epilepsy good
# 952 methylphenidate adhd
# 953 rifaximin diarrhea i
# 954 ethinyl estradiol
# 955 escitalopram anxiety
# 956 magnesium sulfate
# 957 pramoxine hemorrhoid
# 958 amitriptyline pain b
# 959 abilify bipolar diso
# 960 etonogestrel birth c
# 961 nexplanon birth cont
# 962 zestril high blood p
# 963 correctol constipati
# 964 junel fe 1   20 birt
# 965 venlafaxine anxiety
# 966 zolpidem insomnia i
# 967 temazepam insomnia i
# 968 omalizumab urticaria
# 969 miconazole vaginal y
# 970 depo provera abnorma
# 971 blisovi 24 fe birth
# 972 varenicline smoking
# 973 invega schizoaffecti
# 974 isotretinoin acne i
# 975 effexor xr depressio
# 976 euflexxa osteoarthri
# 977 paragard birth contr
# 978 ciprofloxacin urinar
# 979 tramadol pain for a
# 980 amoxicillin upper re
# 981 diphenhydramine inso
# 982 proctofoam hemorrhoi
# 983 propranolol migraine
# 984 naltrexone opiate de
# 985 implanon birth contr
# 986 adapalene acne the b
# 987 canagliflozin diabet
# 988 viibryd depression i
# 989 etonogestrel birth c
# 990 temazepam insomnia o
# 991 sertraline generaliz
# 992 diphenhydramine inso
# 993 lexapro generalized
# 994 vilazodone depressio
# 995 citalopram depressio
# 996 tramadol pain follow
# 997 topamax bipolar diso
# 998 fluoxetine anxiety a
# 999 fetzima major depres
# 1000 prozac anxiety and s
# 1001 desogestrel   ethiny
# 1002 monistat 7 day combi
# 1003 ethinyl estradiol
# 1004 augmentin sinusitis
# 1005 vancomycin bacterial
# 1006 nuvigil narcolepsy i
# 1007 ortho evra birth con
# 1008 ethinyl estradiol
# 1009 asmanex twisthaler a
# 1010 alprazolam anxiety o
# 1011 simply sleep insomni
# 1012 duloxetine back pain
# 1013 paroxetine anxiety a
# 1014 lisinopril high bloo
# 1015 tussionex pennkineti
# 1016 methotrexate rheumat
# 1017 liraglutide diabetes
# 1018 ambien insomnia i ha
# 1019 soolantra rosacea so
# 1020 contrave weight loss
# 1021 chantix smoking cess
# 1022 fenofibrate hypertri
# 1023 adipex p weight loss
# 1024 minocycline acne i a
# 1025 vraylar schizophreni
# 1026 tramadol pain takes
# 1027 lurasidone bipolar d
# 1028 sharobel birth contr
# 1029 lyrica ibromyalgia f
# 1030 methylphenidate adhd
# 1031 trileptal seizures i
# 1032 pramipexole restless
# 1033 macrobid bladder inf
# 1034 miconazole vaginal y
# 1035 alprostadil erectile
# 1036 terbinafine onychomy
# 1037 morphine pain i have
# 1038 tri sprintec birth c
# 1039 liraglutide obesity
# 1040 linzess constipation
# 1041 soma muscle spasm th
# 1042 lacosamide seizures
# 1043 sulfamethoxazole   t
# 1044 olmesartan high bloo
# 1045 azithromycin sinusit
# 1046 belviq weight loss 5
# 1047 clarithromycin strep
# 1048 paroxetine depressio
# 1049 amphetamine   dextro
# 1050 bupropion   naltrexo
# 1051 leuprolide endometri
# 1052 drospirenone   ethin
# 1053 trental intermittent
# 1054 cyclobenzaprine musc
# 1055 zestril high blood p
# 1056 levofloxacin pneumon
# 1057 tocilizumab juvenile
# 1058 ixekizumab plaque ps
# 1059 quetiapine borderlin
# 1060 myrbetriq overactive
# 1061 ethinyl estradiol
# 1062 gabapentin pain i ha
# 1063 naproxen gout  acute
# 1064 accutane acne i love
# 1065 isotretinoin acne i
# 1066 prazosin post trauma
# 1067 bisacodyl constipati
# 1068 dilaudid pain it is
# 1069 venlafaxine depressi
# 1070 tasigna chronic myel
# 1071 armodafinil hypersom
# 1072 desogestrel   ethiny
# 1073 flomax urinary tract
# 1074 junel fe 1   20 birt
# 1075 liraglutide obesity
# 1076 isotretinoin acne i
# 1077 prazosin post trauma
# 1078 viibryd depression i
# 1079 diflucan vaginal yea
# 1080 zaleplon insomnia i
# 1081 niaspan high cholest
# 1082 tacrolimus atopic de
# 1083 indocin sr pain befo
# 1084 mirapex restless leg
# 1085 bisacodyl constipati
# 1086 topamax bulimia i ha
# 1087 naproxen period pain
# 1088 dulcolax constipatio
# 1089 drospirenone   ethin
# 1090 vilazodone depressio
# 1091 lexapro depression a
# 1092 ethinyl estradiol
# 1093 drospirenone   ethin
# 1094 ethinyl estradiol
# 1095 plan b emergency con
# 1096 medroxyprogesterone
# 1097 lorazepam anxiety i
# 1098 venlafaxine depressi
# 1099 bupropion smoking ce
# 1100 olanzapine schizophr
# 1101 isotretinoin acne i
# 1102 seasonique birth con
# 1103 propofol anesthesia
# 1104 st  john own wort de
# 1105 concerta adhd my 13
# 1106 sanctura overactive
# 1107 varenicline smoking
# 1108 silodosin benign pro
# 1109 clomid emale inferti
# 1110 topiramate migraine
# 1111 minastrin 24 fe birt
# 1112 aripiprazole schizoa
# 1113 trazodone insomnia i
# 1114 rivaroxaban deep vei
# 1115 benzoyl peroxide   c
# 1116 dimetapp children ow
# 1117 simbrinza glaucoma
# 1118 neutrasal mucositis
# 1119 tramadol depression
# 1120 dulaglutide diabetes
# 1121 voltaren gel pain i
# 1122 levonorgestrel emerg
# 1123 baclofen alcohol wit
# 1124 nexplanon birth cont
# 1125 metronidazole rosace
# 1126 nexplanon birth cont
# 1127 bisacodyl constipati
# 1128 tioconazole vaginal
# 1129 venlafaxine post tra
# 1130 suvorexant insomnia
# 1131 ciprofloxacin kidney
# 1132 xenical obesity i ha
# 1133 quetiapine insomnia
# 1134 moxifloxacin sinusit
# 1135 orlistat obesity i
# 1136 xulane birth control
# 1137 drospirenone   ethin
# 1138 benlysta systemic lu
# 1139 venlafaxine anxiety
# 1140 aripiprazole agitate
# 1141 adapalene   benzoyl
# 1142 ethinyl estradiol
# 1143 medroxyprogesterone
# 1144 levonorgestrel birth
# 1145 azithromycin pneumon
# 1146 effexor depression e
# 1147 xanax anxiety i have
# 1148 bisacodyl constipati
# 1149 enablex overactive b
# 1150 pregabalin pain i ha
# 1151 alendronate preventi
# 1152 polyethylene glycol
# 1153 paroxetine anxiety i
# 1154 desipramine depressi
# 1155 nitrofurantoin urina
# 1156 pristiq depression i
# 1157 ustekinumab psoriasi
# 1158 atropine   diphenoxy
# 1159 amphetamine   dextro
# 1160 lorcaserin weight lo
# 1161 thiothixene psychosi
# 1162 paliperidone schizop
# 1163 uloric gout first ti
# 1164 amoxicillin   clavul
# 1165 rocephin bacterial i
# 1166 microgestin fe 1   2
# 1167 levonorgestrel birth
# 1168 tolterodine overacti
# 1169 etonogestrel birth c
# 1170 azithromycin pneumon
# 1171 duloxetine ibromyalg
# 1172 dienogest   estradio
# 1173 levonorgestrel birth
# 1174 lorcaserin weight lo
# 1175 lorcaserin obesity h
# 1176 cipro bladder infect
# 1177 medroxyprogesterone
# 1178 fluorouracil keratos
# 1179 nexplanon birth cont
# 1180 ethinyl estradiol
# 1181 pregabalin neuropath
# 1182 wellbutrin xl depres
# 1183 buspar anxiety i hav
# 1184 ethinyl estradiol
# 1185 quetiapine post trau
# 1186 escitalopram general
# 1187 diazepam anxiety i h
# 1188 donepezil mild cogni
# 1189 suvorexant insomnia
# 1190 cialis erectile dysf
# 1191 mirtazapine major de
# 1192 phentermine   topira
# 1193 pentasa crohn own di
# 1194 meloxicam inflammato
# 1195 sprintec abnormal ut
# 1196 abilify obsessive co
# 1197 paliperidone schizop
# 1198 diclofenac osteoarth
# 1199 tamiflu influenza my
# 1200 lisdexamfetamine adh
# 1201 benzonatate cough th
# 1202 varenicline smoking
# 1203 mononessa birth cont
# 1204 vyvanse adhd i have
# 1205 oxycodone pain i use
# 1206 remicade crohn own d
# 1207 etonogestrel birth c
# 1208 buprenorphine   nalo
# 1209 nexplanon birth cont
# 1210 qsymia weight loss j
# 1211 nitrofurantoin bladd
# 1212 finasteride androgen
# 1213 estradiol postmenopa
# 1214 clonazepam insomnia
# 1215 harvoni hepatitis c
# 1216 escitalopram depress
# 1217 drospirenone   ethin
# 1218 dabigatran preventio
# 1219 etonogestrel birth c
# 1220 citalopram anxiety a
# 1221 lorcaserin obesity i
# 1222 sulfamethoxazole   t
# 1223 ms contin chronic pa
# 1224 bupropion   naltrexo
# 1225 ethinyl estradiol
# 1226 concerta adhd my 11
# 1227 sominex insomnia aft
# 1228 levonorgestrel emerg
# 1229 estradiol hypoestrog
# 1230 lyrica ibromyalgia t
# 1231 ethinyl estradiol
# 1232 levonorgestrel abnor
# 1233 ethinyl estradiol
# 1234 zoloft depression to
# 1235 canagliflozin diabet
# 1236 ketorolac pain was p
# 1237 adipex p weight loss
# 1238 brisdelle hot flashe
# 1239 vascepa hypertriglyc
# 1240 desogestrel   ethiny
# 1241 bupropion not listed
# 1242 levonorgestrel birth
# 1243 nortriptyline vulvod
# 1244 losartan high blood
# 1245 ethinyl estradiol
# 1246 venlafaxine depressi
# 1247 oxycontin pain i was
# 1248 adalimumab psoriasis
# 1249 topiramate migraine
# 1250 ethinyl estradiol
# 1251 budesonide   formote
# 1252 escitalopram general
# 1253 naproxen gout  acute
# 1254 buprenorphine   nalo
# 1255 ethinyl estradiol
# 1256 dextromethorphan cou
# 1257 lithium bipolar diso
# 1258 propranolol mance an
# 1259 clindamycin bacteria
# 1260 medroxyprogesterone
# 1261 sertraline depressio
# 1262 suprep bowel prep ki
# 1263 plan b emergency con
# 1264 pentasa crohn own di
# 1265 desvenlafaxine depre
# 1266 thyroid desiccated h
# 1267 simvastatin high cho
# 1268 venlafaxine bipolar
# 1269 miconazole vaginal y
# 1270 paroxetine anxiety a
# 1271 ledipasvir   sofosbu
# 1272 implanon birth contr
# 1273 levonorgestrel birth
# 1274 diphenhydramine inso
# 1275 tramadol pain tramad
# 1276 paroxetine hot flash
# 1277 depo testosterone hy
# 1278 nexplanon birth cont
# 1279 mirena birth control
# 1280 amlodipine high bloo
# 1281 desogestrel   ethiny
# 1282 depo provera abnorma
# 1283 cymbalta ibromyalgia
# 1284 drospirenone   ethin
# 1285 prozac depression i
# 1286 implanon birth contr
# 1287 acetaminophen   hydr
# 1288 phentermine weight l
# 1289 fluconazole vaginal
# 1290 xanax anxiety i had
# 1291 acetylcysteine expec
# 1292 dymista allergic rhi
# 1293 hydrochlorothiazide
# 1294 chantix smoking cess
# 1295 gabapentin bipolar d
# 1296 suboxone opiate depe
# 1297 desvenlafaxine major
# 1298 hydroxyzine anxiety
# 1299 varenicline smoking
# 1300 depo provera abnorma
# 1301 ethinyl estradiol
# 1302 klonopin anxiety i a
# 1303 lorcaserin weight lo
# 1304 phentermine weight l
# 1305 terbinafine tinea cr
# 1306 tretinoin acne i sta
# 1307 duloxetine anxiety s
# 1308 zoloft obsessive com
# 1309 nitrofurantoin urina
# 1310 lasix 33  span  user
# 1311 bupropion   naltrexo
# 1312 advair diskus asthma
# 1313 zoloft depression it
# 1314 neurontin periodic l
# 1315 ethinyl estradiol
# 1316 taltz plaque psorias
# 1317 stalevo parkinson ow
# 1318 pristiq major depres
# 1319 interferon beta 1b m
# 1320 dimenhydrinate motio
# 1321 doxycycline bacteria
# 1322 hydroxyzine anxiety
# 1323 levonorgestrel abnor
# 1324 lo loestrin fe birth
# 1325 nexium gerd i  039 v
# 1326 seroquel schizophren
# 1327 mibelas 24 fe birth
# 1328 magnesium citrate co
# 1329 ethinyl estradiol
# 1330 ethinyl estradiol
# 1331 rosuvastatin high ch
# 1332 chantix smoking cess
# 1333 duloxetine anxiety i
# 1334 adalimumab ankylosin
# 1335 acetaminophen   oxyc
# 1336 sertraline generaliz
# 1337 varenicline smoking
# 1338 brexpiprazole schizo
# 1339 acetaminophen   oxyc
# 1340 infliximab ulcerativ
# 1341 bupropion adhd this
# 1342 venlafaxine ibromyal
# 1343 ethinyl estradiol
# 1344 imuran eczema before
# 1345 acetaminophen   oxyc
# 1346 nuvaring birth contr
# 1347 montelukast bronchos
# 1348 thyroid desiccated u
# 1349 ethinyl estradiol
# 1350 nexplanon birth cont
# 1351 nucynta pain i tried
# 1352 yaz birth control i
# 1353 saxenda weight loss
# 1354 humira crohn own dis
# 1355 trinessa birth contr
# 1356 promethazine nausea
# 1357 vyvanse adhd i  039
# 1358 linaclotide constipa
# 1359 aluminum chloride he
# 1360 asacol ulcerative co
# 1361 marlissa birth contr
# 1362 strattera adhd i  03
# 1363 quetiapine bipolar d
# 1364 depo provera birth c
# 1365 aluminum chloride he
# 1366 suprep bowel prep ki
# 1367 simponi ankylosing s
# 1368 trazodone ibromyalgi
# 1369 adipex p weight loss
# 1370 dimethyl fumarate mu
# 1371 albuterol asthma  ma
# 1372 symbicort asthma  ma
# 1373 ethinyl estradiol
# 1374 hydrochlorothiazide
# 1375 olanzapine paranoid
# 1376 vilazodone major dep
# 1377 belviq weight loss i
# 1378 diazepam anxiety i h
# 1379 mirena birth control
# 1380 ethinyl estradiol
# 1381 abilify bipolar diso
# 1382 estarylla birth cont
# 1383 elavil anxiety and s
# 1384 qsymia obesity i hav
# 1385 nuvigil shift work s
# 1386 velivet birth contro
# 1387 levocetirizine urtic
# 1388 tramadol back pain a
# 1389 kineret schnitzler s
# 1390 hycodan cough took i
# 1391 edex erectile dysfun
# 1392 phentermine weight l
# 1393 strattera adhd i hav
# 1394 xifaxan irritable bo
# 1395 fluticasone   vilant
# 1396 aluminum chloride he
# 1397 phentermine   topira
# 1398 kombiglyze xr diabet
# 1399 levonorgestrel emerg
# 1400 clonidine opiate wit
# 1401 ethinyl estradiol
# 1402 levonorgestrel emerg
# 1403 pregabalin ibromyalg
# 1404 ultram pain i have b
# 1405 kyleena 17  span  us
# 1406 copper birth control
# 1407 suprep bowel prep ki
# 1408 azithromycin bronchi
# 1409 amitiza constipation
# 1410 montelukast asthma s
# 1411 boniva osteoporosis
# 1412 accutane acne i had
# 1413 trintellix major dep
# 1414 terconazole vaginal
# 1415 etonogestrel birth c
# 1416 ethinyl estradiol
# 1417 dilaudid pain works
# 1418 xyzal allergies this
# 1419 nexplanon birth cont
# 1420 cozaar high blood pr
# 1421 sumatriptan cluster
# 1422 buspirone anxiety i
# 1423 miconazole vaginal y
# 1424 plan b emergency con
# 1425 ethinyl estradiol
# 1426 flecainide atrial fi
# 1427 drysol hyperhidrosis
# 1428 xarelto pulmonary em
# 1429 levonorgestrel birth
# 1430 desvenlafaxine depre
# 1431 phentermine weight l
# 1432 tioconazole vaginal
# 1433 etonogestrel birth c
# 1434 lorazepam sedation 5
# 1435 vilazodone depressio
# 1436 sucralfate gerd i  0
# 1437 escitalopram depress
# 1438 dulcolax constipatio
# 1439 fluoxetine anxiety a
# 1440 duragesic chronic pa
# 1441 clindamycin bacteria
# 1442 methotrexate rheumat
# 1443 sansert cluster head
# 1444 levonorgestrel birth
# 1445 ethinyl estradiol
# 1446 abilify bipolar diso
# 1447 levonorgestrel birth
# 1448 copper birth control
# 1449 mirena birth control
# 1450 alprazolam anxiety i
# 1451 lidoderm postherpeti
# 1452 depo provera abnorma
# 1453 etonogestrel birth c
# 1454 levonorgestrel birth
# 1455 miconazole vaginal y
# 1456 miconazole vaginal y
# 1457 daytrana adhd my son
# 1458 miconazole vaginal y
# 1459 acetaminophen   hydr
# 1460 aubra birth control
# 1461 nucynta pain nucynta
# 1462 rizatriptan migraine
# 1463 ambien insomnia grea
# 1464 levitra erectile dys
# 1465 flomax benign prosta
# 1466 mirena birth control
# 1467 cephalexin bacterial
# 1468 emtricitabine   teno
# 1469 geodon bipolar disor
# 1470 phentermine weight l
# 1471 ethinyl estradiol
# 1472 temazepam insomnia i
# 1473 boniva osteoporosis
# 1474 jardiance diabetes
# 1475 skyla birth control
# 1476 gildess fe 1 5   30
# 1477 lidoderm pain i trie
# 1478 varenicline smoking
# 1479 cefdinir bronchitis
# 1480 sulfamethoxazole   t
# 1481 adapalene   benzoyl
# 1482 premphase postmenopa
# 1483 viibryd depression d
# 1484 modafinil chronic fa
# 1485 etonogestrel birth c
# 1486 emtricitabine   rilp
# 1487 remeron depression d
# 1488 complera hiv infecti
# 1489 levonorgestrel birth
# 1490 eluxadoline irritabl
# 1491 dalfampridine multip
# 1492 terbinafine onychomy
# 1493 vortioxetine major d
# 1494 ethinyl estradiol
# 1495 guaifenesin   pseudo
# 1496 levonorgestrel emerg
# 1497 ethinyl estradiol
# 1498 sertraline depressio
# 1499 lorcaserin weight lo
# 1500 dramamine motion sic
# 1501 drospirenone   ethin
# 1502 duloxetine ibromyalg
# 1503 diazepam anxiety no
# 1504 levothyroxine undera
# 1505 valium muscle spasm
# 1506 buprenorphine pain w
# 1507 cipro urinary tract
# 1508 vortioxetine major d
# 1509 sprintec birth contr
# 1510 testim hypogonadism
# 1511 errin birth control
# 1512 seroquel bipolar dis
# 1513 alprazolam panic dis
# 1514 norethindrone birth
# 1515 duac acne i used dua
# 1516 infliximab ankylosin
# 1517 metoprolol high bloo
# 1518 aspirin   butalbital
# 1519 quetiapine post trau
# 1520 mucinex d cough and
# 1521 magnesium sulfate
# 1522 macrobid urinary tra
# 1523 famotidine   ibuprof
# 1524 aripiprazole autism
# 1525 dulaglutide diabetes
# 1526 dextromethorphan cou
# 1527 lorazepam anxiety wo
# 1528 etonogestrel birth c
# 1529 zoloft panic disorde
# 1530 cymbalta ibromyalgia
# 1531 accutane acne this d
# 1532 azelastine allergic
# 1533 estradiol postmenopa
# 1534 tacrolimus atopic de
# 1535 divalproex sodium mi
# 1536 oxycodone pain this
# 1537 ethinyl estradiol
# 1538 kyleena birth contro
# 1539 drospirenone   ethin
# 1540 levonorgestrel birth
# 1541 zetia high cholester
# 1542 latuda schizoaffecti
# 1543 suprep bowel prep ki
# 1544 dilaudid pain this m
# 1545 ethinyl estradiol
# 1546 levonorgestrel birth
# 1547 macrobid bladder inf
# 1548 oxycodone pain best
# 1549 monistat 3 day combi
# 1550 nexplanon birth cont
# 1551 apri birth control i
# 1552 esomeprazole gerd no
# 1553 lo loestrin fe birth
# 1554 octreotide diabetes
# 1555 olanzapine schizophr
# 1556 belviq weight loss i
# 1557 natazia menorrhagia
# 1558 lexapro depression t
# 1559 nivolumab melanoma m
# 1560 gabapentin neuropath
# 1561 loperamide diarrhea
# 1562 adipex p weight loss
# 1563 bisacodyl constipati
# 1564 chantix smoking cess
# 1565 duloxetine diabetic
# 1566 miralax constipation
# 1567 sprintec birth contr
# 1568 desipramine depressi
# 1569 nexplanon birth cont
# 1570 humira psoriatic art
# 1571 abilify depression t
# 1572 xanax anxiety the 1m
# 1573 klonopin panic disor
# 1574 acetaminophen   hydr
# 1575 betaseron multiple s
# 1576 lurasidone bipolar d
# 1577 diazepam temporomand
# 1578 zyprexa depression r
# 1579 skyla birth control
# 1580 desvenlafaxine depre
# 1581 ethinyl estradiol
# 1582 lexapro depression g
# 1583 golytely bowel prepa
# 1584 levsin sl crohn own
# 1585 accutane acne i have
# 1586 etonogestrel birth c
# 1587 vyvanse adhd i am a
# 1588 propranolol mance an
# 1589 benzonatate cough ha
# 1590 diclofenac pain best
# 1591 ethinyl estradiol
# 1592 methadone chronic pa
# 1593 cialis erectile dysf
# 1594 levetiracetam seizur
# 1595 fluoxetine obsessive
# 1596 lisdexamfetamine bin
# 1597 medroxyprogesterone
# 1598 nexplanon birth cont
# 1599 cyclobenzaprine musc
# 1600 mirena birth control
# 1601 ethinyl estradiol
# 1602 suprep bowel prep ki
# 1603 acetaminophen   hydr
# 1604 soma muscle spasm i
# 1605 clindamycin acne im
# 1606 etonogestrel birth c
# 1607 cipro urinary tract
# 1608 edarbyclor high bloo
# 1609 fluconazole tinea ve
# 1610 guaifenesin   pseudo
# 1611 propranolol mance an
# 1612 escitalopram general
# 1613 implanon birth contr
# 1614 nucynta er pain in 2
# 1615 ethinyl estradiol
# 1616 exenatide diabetes
# 1617 minastrin 24 fe birt
# 1618 lyrica neuropathic p
# 1619 estarylla birth cont
# 1620 rexulti major depres
# 1621 chantix smoking cess
# 1622 lubiprostone irritab
# 1623 plan b emergency con
# 1624 linzess constipation
# 1625 fentanyl pain finall
# 1626 levonorgestrel emerg
# 1627 fluticasone   salmet
# 1628 ethinyl estradiol
# 1629 linagliptin diabetes
# 1630 bydureon diabetes  t
# 1631 etonogestrel birth c
# 1632 atripla hiv infectio
# 1633 amitriptyline ibromy
# 1634 quetiapine generaliz
# 1635 isotretinoin acne th
# 1636 tramadol chronic pai
# 1637 ethinyl estradiol
# 1638 olanzapine bipolar d
# 1639 levofloxacin sinusit
# 1640 monodox acne low sel
# 1641 nexplanon birth cont
# 1642 trazodone anxiety i
# 1643 aprepitant nausea vo
# 1644 duloxetine depressio
# 1645 testosterone hypogon
# 1646 zofran nausea vomiti
# 1647 buprenorphine chroni
# 1648 nexplanon birth cont
# 1649 liraglutide weight l
# 1650 sulfamethoxazole   t
# 1651 medroxyprogesterone
# 1652 ethinyl estradiol
# 1653 fluoxetine depressio
# 1654 zepatier hepatitis c
# 1655 prazosin post trauma
# 1656 lamotrigine not list
# 1657 lorazepam insomnia t
# 1658 tenuate dospan obesi
# 1659 pancrelipase pancrea
# 1660 estradiol hypoestrog
# 1661 avelox bronchitis a
# 1662 cellcept 12  span  u
# 1663 buprenorphine   nalo
# 1664 valtrex herpes simpl
# 1665 depo provera birth c
# 1666 levonorgestrel birth
# 1667 levoxyl hashimoto ow
# 1668 lunesta 10  span  us
# 1669 lorazepam anxiety th
# 1670 levonorgestrel birth
# 1671 meloxicam osteoarthr
# 1672 varenicline smoking
# 1673 accutane acne i  039
# 1674 tretinoin acne i hav
# 1675 prednisone sinusitis
# 1676 phentermine weight l
# 1677 fexofenadine allergi
# 1678 cymbalta depression
# 1679 paroxetine social an
# 1680 mirena birth control
# 1681 etonogestrel birth c
# 1682 lo loestrin fe birth
# 1683 chaparral herbal sup
# 1684 tri sprintec birth c
# 1685 quetiapine bipolar d
# 1686 lorazepam anxiety th
# 1687 orthovisc osteoarthr
# 1688 ethinyl estradiol
# 1689 guaifenesin ibromyal
# 1690 sertraline depressio
# 1691 drospirenone   ethin
# 1692 suvorexant insomnia
# 1693 tramadol chronic pai
# 1694 implanon birth contr
# 1695 tacrolimus atopic de
# 1696 metronidazole tricho
# 1697 clonazepam panic dis
# 1698 celexa depression i
# 1699 ethinyl estradiol
# 1700 drospirenone   ethin
# 1701 cyanocobalamin vitam
# 1702 suvorexant insomnia
# 1703 escitalopram depress
# 1704 buspirone anxiety i
# 1705 sertraline obsessive
# 1706 nicorette smoking ce
# 1707 buprenorphine   nalo
# 1708 trintellix depressio
# 1709 buspar panic disorde
# 1710 aviane birth control
# 1711 suboxone opiate depe
# 1712 cryselle birth contr
# 1713 levonorgestrel emerg
# 1714 medroxyprogesterone
# 1715 nitrofurantoin urina
# 1716 fentanyl pain i was
# 1717 famciclovir cold sor
# 1718 selegiline depressio
# 1719 adapalene acne i  03
# 1720 ortho evra birth con
# 1721 linagliptin diabetes
# 1722 venlafaxine depressi
# 1723 mirtazapine depressi
# 1724 bupropion   naltrexo
# 1725 temazepam insomnia b
# 1726 accutane acne i  am
# 1727 apri birth control i
# 1728 oseltamivir influenz
# 1729 fentanyl pain having
# 1730 prozac depression af
# 1731 nucynta er pain i ha
# 1732 blisovi 24 fe birth
# 1733 actos diabetes  type
# 1734 tramadol pain i have
# 1735 rosuvastatin high ch
# 1736 nexplanon birth cont
# 1737 visine totality mult
# 1738 naltrexone ibromyalg
# 1739 taytulla birth contr
# 1740 minocycline acne hon
# 1741 belsomra insomnia th
# 1742 temazepam insomnia b
# 1743 bupropion   naltrexo
# 1744 flagyl bacterial inf
# 1745 acetaminophen   oxyc
# 1746 tramadol back pain i
# 1747 paroxetine hot flash
# 1748 topamax obesity this
# 1749 levonorgestrel emerg
# 1750 zyclara keratosis i
# 1751 paxil social anxiety
# 1752 xylocaine jelly pain
# 1753 bupropion adhd i  03
# 1754 depo provera abnorma
# 1755 ortho evra birth con
# 1756 tramadol depression
# 1757 drospirenone   ethin
# 1758 naproxen   sumatript
# 1759 etonogestrel birth c
# 1760 ethinyl estradiol
# 1761 amitriptyline ibromy
# 1762 provigil shift work
# 1763 phentermine weight l
# 1764 eluxadoline irritabl
# 1765 lisdexamfetamine adh
# 1766 nexplanon birth cont
# 1767 plan b emergency con
# 1768 ranitidine stomach u
# 1769 diazepam anxiety i a
# 1770 clonazepam anxiety i
# 1771 azor high blood pres
# 1772 menthol   zinc oxide
# 1773 vivitrol opiate depe
# 1774 generess fe birth co
# 1775 aubra birth control
# 1776 sodium biphosphate
# 1777 phentermine weight l
# 1778 nexplanon birth cont
# 1779 ethinyl estradiol
# 1780 lovenox deep vein th
# 1781 bisacodyl   polyethy
# 1782 balsam peru   castor
# 1783 sotalol atrial fibri
# 1784 abacavir   dolutegra
# 1785 ethinyl estradiol
# 1786 thyroid desiccated u
# 1787 venlafaxine anxiety
# 1788 levonorgestrel birth
# 1789 bupropion smoking ce
# 1790 nexium gerd very eff
# 1791 asenapine post traum
# 1792 horizant postherpeti
# 1793 ethinyl estradiol
# 1794 norethindrone birth
# 1795 vilazodone depressio
# 1796 levonorgestrel birth
# 1797 orsythia birth contr
# 1798 citalopram anxiety a
# 1799 aldara keratosis pos
# 1800 naproxen   sumatript
# 1801 adipex p weight loss
# 1802 azelastine allergic
# 1803 aripiprazole obsessi
# 1804 topamax migraine pre
# 1805 olopatadine seasonal
# 1806 hydroxyzine anxiety
# 1807 miconazole vaginal y
# 1808 amlodipine migraine
# 1809 methotrexate rheumat
# 1810 requip restless legs
# 1811 camrese birth contro
# 1812 opsumit pulmonary hy
# 1813 klonopin anxiety klo
# 1814 ortho micronor birth
# 1815 ethinyl estradiol
# 1816 lorcaserin weight lo
# 1817 tretinoin photoaging
# 1818 acetazolamide glauco
# 1819 ethinyl estradiol
# 1820 naproxen gout  acute
# 1821 naloxegol opioid ind
# 1822 etonogestrel birth c
# 1823 olanzapine major dep
# 1824 bupropion   naltrexo
# 1825 etonogestrel birth c
# 1826 lisinopril migraine
# 1827 implanon birth contr
# 1828 lo loestrin fe birth
# 1829 klonopin panic disor
# 1830 ultram restless legs
# 1831 methylphenidate adhd
# 1832 suprep bowel prep ki
# 1833 varenicline smoking
# 1834 sildenafil erectile
# 1835 tavaborole onychomyc
# 1836 implanon birth contr
# 1837 gabapentin migraine
# 1838 etodolac osteoarthri
# 1839 pantoprazole gerd i
# 1840 requip restless legs
# 1841 celexa anxiety and s
# 1842 sertraline depressio
# 1843 azathioprine crohn o
# 1844 vortioxetine depress
# 1845 doxycycline acne i
# 1846 lamotrigine depressi
# 1847 prozac anxiety and s
# 1848 ethinyl estradiol
# 1849 zyprexa bipolar diso
# 1850 nexplanon birth cont
# 1851 drospirenone   ethin
# 1852 effexor xr postpartu
# 1853 vimovo 39  span  use
# 1854 carbamazepine bipola
# 1855 xyzal 5  span  users
# 1856 univasc high blood p
# 1857 suvorexant insomnia
# 1858 ciprofloxacin urinar
# 1859 librium anxiety libr
# 1860 mirtazapine anxiety
# 1861 prazosin post trauma
# 1862 eluxadoline irritabl
# 1863 drospirenone   ethin
# 1864 abilify major depres
# 1865 zovirax herpes simpl
# 1866 hyaluronan osteoarth
# 1867 suboxone opiate depe
# 1868 promethazine nausea
# 1869 adalimumab psoriasis
# 1870 contrave obesity i h
# 1871 ethinyl estradiol
# 1872 amphetamine   dextro
# 1873 lunesta insomnia lun
# 1874 estarylla birth cont
# 1875 estradiol postmenopa
# 1876 dulaglutide diabetes
# 1877 nuvaring birth contr
# 1878 clarithromycin bronc
# 1879 risperidone bipolar
# 1880 disulfiram alcohol d
# 1881 niacin high choleste
# 1882 vyvanse adhd i start
# 1883 nexplanon birth cont
# 1884 xulane birth control
# 1885 stelara psoriasis st
# 1886 remicade crohn own d
# 1887 tenuate obesity i ha
# ...
# 10168 lexapro anxiety have
# 10169 antabuse alcohol dep
# 10170 bupropion bipolar di
# 10171 sertraline major dep
# 10172 eluxadoline irritabl
# 10173 sprintec birth contr
# 10174 contrave obesity i a
# 10175 suprep bowel prep ki
# 10176 paroxetine anxiety s
# 10177 amphetamine   dextro
# 10178 clonazepam anxiety p
# 10179 suprep bowel prep ki
# 10180 polyethylene glycol
# 10181 ramipril high blood
# 10182 hydrocodone pain i s
# 10183 pletal intermittent
# 10184 ramelteon insomnia i
# 10185 clindamycin acne i u
# 10186 dexamethasone nausea
# 10187 hydrocodone   ibupro
# 10188 methotrexate psorias
# 10189 lorcaserin weight lo
# 10190 atenolol anxiety wor
# 10191 allegra allergic rhi
# 10192 amlodipine high bloo
# 10193 ustekinumab psoriasi
# 10194 oxymorphone pain i h
# 10195 clonazepam anxiety i
# 10196 duloxetine depressio
# 10197 harvoni hepatitis c
# 10198 prozac anxiety and s
# 10199 saxenda weight loss
# 10200 levonorgestrel emerg
# 10201 femcon fe birth cont
# 10202 brimonidine rosacea
# 10203 drospirenone   ethin
# 10204 dulcolax constipatio
# 10205 sertraline anxiety a
# 10206 sumavel dosepro migr
# 10207 zonegran migraine pr
# 10208 ortho tri cyclen lo
# 10209 benzonatate cough do
# 10210 ziana acne hope this
# 10211 nitrofurantoin urina
# 10212 kariva birth control
# 10213 eylea diabetic macul
# 10214 ethinyl estradiol
# 10215 stadol pain omg i wa
# 10216 ketorolac pain i had
# 10217 montelukast allergic
# 10218 estradiol postmenopa
# 10219 carisoprodol muscle
# 10220 alprazolam panic dis
# 10221 olanzapine insomnia
# 10222 alprazolam anxiety i
# 10223 strattera adhd i hav
# 10224 topiramate migraine
# 10225 lorazepam nausea vom
# 10226 benzoyl peroxide   c
# 10227 lyrica reflex sympat
# 10228 ethinyl estradiol
# 10229 zantac 150 gerd tire
# 10230 januvia diabetes  ty
# 10231 viibryd major depres
# 10232 bisacodyl constipati
# 10233 meridia obesity i st
# 10234 norethindrone birth
# 10235 prolia osteoporosis
# 10236 androgel hypogonadis
# 10237 methadone chronic pa
# 10238 lurasidone bipolar d
# 10239 acetaminophen   code
# 10240 otezla plaque psoria
# 10241 doxycycline acne i
# 10242 dextromethorphan cou
# 10243 valacyclovir cold so
# 10244 breo ellipta copd my
# 10245 zorvolex osteoarthri
# 10246 atomoxetine adhd i w
# 10247 xyzal allergies best
# 10248 acetaminophen   buta
# 10249 tacrolimus organ tra
# 10250 carvedilol high bloo
# 10251 metoprolol high bloo
# 10252 quetiapine post trau
# 10253 amlodipine high bloo
# 10254 levonorgestrel birth
# 10255 levora birth control
# 10256 ciprofloxacin bladde
# 10257 saphris schizophreni
# 10258 buprenorphine   nalo
# 10259 miconazole vaginal y
# 10260 trinessa birth contr
# 10261 bentyl irritable bow
# 10262 liraglutide obesity
# 10263 medroxyprogesterone
# 10264 nexplanon birth cont
# 10265 testim hypogonadism
# 10266 eluxadoline irritabl
# 10267 errin endometriosis
# 10268 phentermine weight l
# 10269 estradiol atrophic v
# 10270 aczone acne i have u
# 10271 ethinyl estradiol
# 10272 bentyl irritable bow
# 10273 phentermine   topira
# 10274 clarinex allergic rh
# 10275 ethinyl estradiol
# 10276 gardasil 8  span  us
# 10277 dymista allergic rhi
# 10278 levonorgestrel birth
# 10279 amoxicillin   clavul
# 10280 nexplanon birth cont
# 10281 insulin detemir diab
# 10282 azithromycin sinusit
# 10283 xanax panic disorde
# 10284 insulin aspart diabe
# 10285 drospirenone   ethin
# 10286 loryna birth control
# 10287 meloxicam osteoarthr
# 10288 tioconazole vaginal
# 10289 acyclovir herpes sim
# 10290 benicar high blood p
# 10291 myrbetriq overactive
# 10292 monistat 7 vaginal y
# 10293 vyvanse adhd i  039
# 10294 lorazepam nausea vom
# 10295 benzoyl peroxide   c
# 10296 erlotinib non small
# 10297 ativan nausea vomiti
# 10298 lidocaine pain works
# 10299 phentermine weight l
# 10300 ethinyl estradiol
# 10301 duloxetine ibromyalg
# 10302 gildess fe 1   20 me
# 10303 escitalopram anxiety
# 10304 infliximab crohn own
# 10305 oxycodone pain i  03
# 10306 mirena birth control
# 10307 ketorolac pain i hav
# 10308 ethinyl estradiol
# 10309 rivaroxaban pulmonar
# 10310 fioricet headache th
# 10311 plan b one step emer
# 10312 depo provera birth c
# 10313 lisinopril high bloo
# 10314 escitalopram general
# 10315 losartan high blood
# 10316 viibryd depression i
# 10317 geodon schizoaffecti
# 10318 phentermine weight l
# 10319 amoxicillin   clavul
# 10320 yaz 1  span  users f
# 10321 azithromycin bronchi
# 10322 aspirin back pain ha
# 10323 duloxetine depressio
# 10324 olanzapine bipolar d
# 10325 trazodone insomnia i
# 10326 trinessa acne i just
# 10327 ethinyl estradiol
# 10328 valium anxiety i  03
# 10329 alprazolam anxiety l
# 10330 fluocinolone dermati
# 10331 tavaborole onychomyc
# 10332 acetaminophen   oxyc
# 10333 sprintec birth contr
# 10334 valium anxiety excel
# 10335 inderal benign essen
# 10336 oxycodone pain takes
# 10337 norel sr nasal conge
# 10338 tussionex pennkineti
# 10339 vortioxetine major d
# 10340 zoloft depression i
# 10341 dulcolax constipatio
# 10342 citalopram generaliz
# 10343 suboxone opiate depe
# 10344 magnesium sulfate
# 10345 acetaminophen   hydr
# 10346 etonogestrel birth c
# 10347 phentermine weight l
# 10348 asacol crohn own dis
# 10349 hydroxychloroquine r
# 10350 flagyl bacterial inf
# 10351 aluminum chloride he
# 10352 nexium gerd i though
# 10353 acetaminophen   hydr
# 10354 nexplanon birth cont
# 10355 topiramate ibromyalg
# 10356 risperdal m tab auti
# 10357 tioconazole vaginal
# 10358 vardenafil erectile
# 10359 dulera asthma it has
# 10360 epiduo acne have bee
# 10361 ethinyl estradiol
# 10362 victoza diabetes  ty
# 10363 orlistat obesity wor
# 10364 succinylcholine anes
# 10365 cipro bronchitis eli
# 10366 divalproex sodium bi
# 10367 miconazole vaginal y
# 10368 simply sleep insomni
# 10369 naproxen tendonitis
# 10370 entacapone parkinson
# 10371 lorazepam anxiety i
# 10372 xulane birth control
# 10373 copper birth control
# 10374 fortesta hypogonadis
# 10375 contrave obesity fir
# 10376 efavirenz   emtricit
# 10377 amoxicillin   clavul
# 10378 etonogestrel birth c
# 10379 celexa generalized a
# 10380 desvenlafaxine depre
# 10381 pemoline adhd i star
# 10382 fluoxetine depressio
# 10383 levonorgestrel emerg
# 10384 zovirax herpes simpl
# 10385 diclofenac migraine
# 10386 imuran crohn own dis
# 10387 ethinyl estradiol
# 10388 ethinyl estradiol
# 10389 plan b one step emer
# 10390 testosterone hypogon
# 10391 magnesium sulfate
# 10392 etonogestrel birth c
# 10393 reclipsen birth cont
# 10394 liraglutide obesity
# 10395 levothyroxine tsh su
# 10396 sertraline depressio
# 10397 contrave weight loss
# 10398 zioptan glaucoma  op
# 10399 clonidine high blood
# 10400 mirvaso rosacea it t
# 10401 ziprasidone schizoph
# 10402 magnesium citrate co
# 10403 medroxyprogesterone
# 10404 nucynta pain had no
# 10405 varenicline smoking
# 10406 pregabalin generaliz
# 10407 chlordiazepoxide alc
# 10408 dexilant 22  span  u
# 10409 diethylpropion obesi
# 10410 lamictal bipolar dis
# 10411 benzonatate cough ch
# 10412 buprenorphine   nalo
# 10413 bupropion   naltrexo
# 10414 intuniv adhd i am cu
# 10415 drospirenone   ethin
# 10416 lorcaserin obesity i
# 10417 methylphenidate depr
# 10418 amoxicillin   clavul
# 10419 bupropion depression
# 10420 provera amenorrhea i
# 10421 venlafaxine social a
# 10422 loestrin 24 fe birth
# 10423 minocycline acne i s
# 10424 liraglutide obesity
# 10425 amitriptyline depres
# 10426 phentermine   topira
# 10427 pristiq depression i
# 10428 leflunomide rheumato
# 10429 trulicity diabetes
# 10430 phentermine weight l
# 10431 paxil anxiety and st
# 10432 amerge migraine work
# 10433 moxifloxacin bronchi
# 10434 risperidone schizoaf
# 10435 focalin adhd this wa
# 10436 lamotrigine bipolar
# 10437 gildess fe 1   20 bi
# 10438 abreva herpes simple
# 10439 effexor xr depressio
# 10440 bupropion   naltrexo
# 10441 trazodone insomnia m
# 10442 zoloft social anxiet
# 10443 methotrexate rheumat
# 10444 sprintec birth contr
# 10445 benlysta systemic lu
# 10446 topamax migraine pre
# 10447 quetiapine borderlin
# 10448 dextromethorphan cou
# 10449 amlodipine   valsart
# 10450 prednisone rheumatoi
# 10451 liraglutide diabetes
# 10452 strattera adhd my so
# 10453 daytrana adhd my 9yr
# 10454 bupropion   naltrexo
# 10455 amoxicillin bacteria
# 10456 wellbutrin xl major
# 10457 fesoterodine overact
# 10458 acetaminophen   prop
# 10459 ziana acne i have ha
# 10460 sertraline depressio
# 10461 medroxyprogesterone
# 10462 lisdexamfetamine adh
# 10463 skyla birth control
# 10464 depo provera birth c
# 10465 disulfiram alcohol d
# 10466 lyrica ibromyalgia i
# 10467 phentermine weight l
# 10468 olanzapine bipolar d
# 10469 citalopram depressio
# 10470 pregabalin periphera
# 10471 wellbutrin depressio
# 10472 etonogestrel birth c
# 10473 iron polysaccharide
# 10474 liraglutide weight l
# 10475 mirabegron overactiv
# 10476 synthroid underactiv
# 10477 levonorgestrel birth
# 10478 diphenhydramine naus
# 10479 butrans pain i have
# 10480 microgestin fe 1   2
# 10481 wellbutrin depressio
# 10482 oxycodone pain i hav
# 10483 victoza obesity i  0
# 10484 metaxalone muscle sp
# 10485 penciclovir cold sor
# 10486 ethinyl estradiol
# 10487 acetazolamide pseudo
# 10488 ethinyl estradiol
# 10489 omalizumab urticaria
# 10490 polyethylene glycol
# 10491 trazodone insomnia 5
# 10492 varenicline smoking
# 10493 clindamycin bacteria
# 10494 nifedipine raynaud o
# 10495 acetaminophen   dich
# 10496 lamotrigine seizure
# 10497 concerta adhd i am a
# 10498 buspirone anxiety th
# 10499 clonidine adhd my 6
# 10500 plan b emergency con
# 10501 hytrin high blood pr
# 10502 asenapine schizoaffe
# 10503 ethinyl estradiol
# 10504 varenicline smoking
# 10505 sertraline depressio
# 10506 epiduo acne my dr pr
# 10507 metronidazole helico
# 10508 tavaborole onychomyc
# 10509 singulair asthma thi
# 10510 implanon birth contr
# 10511 azithromycin chlamyd
# 10512 methylphenidate adhd
# 10513 xanax anxiety i am p
# 10514 imiquimod keratosis
# 10515 levonorgestrel abnor
# 10516 adipex p obesity sta
# 10517 bisacodyl constipati
# 10518 fluticasone   salmet
# 10519 depakote er migraine
# 10520 janumet diabetes  ty
# 10521 bupropion depression
# 10522 oxybutynin overactiv
# 10523 meclizine vertig i
# 10524 plan b one step emer
# 10525 nexplanon birth cont
# 10526 pregabalin neuropath
# 10527 levora birth control
# 10528 versed light sedatio
# 10529 lexapro depression i
# 10530 fentanyl chronic pai
# 10531 liraglutide obesity
# 10532 citalopram obsessive
# 10533 testosterone hypogon
# 10534 sertraline major dep
# 10535 mirena abnormal uter
# 10536 ethinyl estradiol
# 10537 orsythia birth contr
# 10538 escitalopram general
# 10539 ethinyl estradiol
# 10540 trintellix major dep
# 10541 propranolol high blo
# 10542 jublia onychomycosis
# 10543 suvorexant insomnia
# 10544 phentermine weight l
# 10545 spironolactone acne
# 10546 benzoyl peroxide   c
# 10547 citalopram anxiety a
# 10548 maxalt mlt migraine
# 10549 arixtra pulmonary em
# 10550 adderall xr adhd i l
# 10551 trazodone insomnia i
# 10552 diclegis nausea vomi
# 10553 calamine pruritus i
# 10554 acetaminophen   oxyc
# 10555 benzoyl peroxide   c
# 10556 linzess constipation
# 10557 levonorgestrel birth
# 10558 benzoyl peroxide   c
# 10559 contrave obesity i h
# 10560 effexor anxiety and
# 10561 miconazole vaginal y
# 10562 etonogestrel birth c
# 10563 metronidazole bacter
# 10564 lorazepam anxiety ha
# 10565 remicade ulcerative
# 10566 escitalopram general
# 10567 prednisone osteoarth
# 10568 victoza diabetes  ty
# 10569 rapaflo benign prost
# 10570 cariprazine bipolar
# 10571 arformoterol moterol
# 10572 nexplanon birth cont
# 10573 magnesium hydroxide
# 10574 tioconazole vaginal
# 10575 onabotulinumtoxina o
# 10576 duloxetine ibromyalg
# 10577 mucinex ibromyalgia
# 10578 trinessa birth contr
# 10579 humira ankylosing sp
# 10580 phenazopyridine inte
# 10581 zomig migraine i was
# 10582 etonogestrel birth c
# 10583 exenatide diabetes
# 10584 phentermine   topira
# 10585 nitrofurantoin bladd
# 10586 levaquin pneumonia i
# 10587 androgel hypogonadis
# 10588 citalopram anxiety a
# 10589 celexa depression th
# 10590 promethazine sedatio
# 10591 canagliflozin diabet
# 10592 junel fe 1   20 birt
# 10593 adapalene   benzoyl
# 10594 chantix smoking cess
# 10595 buprenorphine opiate
# 10596 fluoxetine depressio
# 10597 paclitaxel breast ca
# 10598 levonorgestrel birth
# 10599 levonorgestrel emerg
# 10600 linzess constipation
# 10601 lidex psoriasis i us
# 10602 ramelteon insomnia i
# 10603 bupropion   naltrexo
# 10604 prepopik bowel prepa
# 10605 depakote bipolar dis
# 10606 cariprazine schizoph
# 10607 benzoyl peroxide   c
# 10608 clonazepam restless
# 10609 cobicistat   elviteg
# 10610 ethinyl estradiol
# 10611 temazepam insomnia i
# 10612 yaz acne yaz made me
# 10613 sulfamethoxazole   t
# 10614 methylphenidate adhd
# 10615 zocor high cholester
# 10616 quinine nocturnal le
# 10617 liraglutide diabetes
# 10618 dalfampridine multip
# 10619 cyclobenzaprine musc
# 10620 canagliflozin diabet
# 10621 wellbutrin depressio
# 10622 drospirenone   ethin
# 10623 imitrex cluster head
# 10624 mirena birth control
# 10625 gildess fe 1   20 bi
# 10626 lyrica diabetic peri
# 10627 acetaminophen   hydr
# 10628 desogestrel   ethiny
# 10629 zetia high cholester
# 10630 tadalafil erectile d
# 10631 prochlorperazine nau
# 10632 imodium diarrhea i h
# 10633 ethinyl estradiol
# 10634 lexapro depression a
# 10635 temazepam insomnia w
# 10636 skelaxin muscle spas
# 10637 hydrocodone pain i h
# 10638 nexplanon birth cont
# 10639 tofranil panic disor
# 10640 multivitamin dietary
# 10641 gabapentin restless
# 10642 testosterone hypogon
# 10643 concerta adhd i have
# 10644 xanax panic disorde
# 10645 mirtazapine depressi
# 10646 ethinyl estradiol
# 10647 topiramate migraine
# 10648 trinessa birth contr
# 10649 tri previfem birth c
# 10650 montelukast allergic
# 10651 ketorolac pain used
# 10652 klonopin anxiety giv
# 10653 escitalopram anxiety
# 10654 etonogestrel birth c
# 10655 methadone opiate wit
# 10656 ethinyl estradiol
# 10657 adalimumab crohn own
# 10658 phentermine weight l
# 10659 doxycycline skin or
# 10660 ethinyl estradiol
# 10661 medroxyprogesterone
# 10662 lyrica 21  span  use
# 10663 estradiol postmenopa
# 10664 ethinyl estradiol
# 10665 pristiq depression i
# 10666 clonazepam panic dis
# 10667 meprobamate anxiety
# 10668 desvenlafaxine depre
# 10669 ethinyl estradiol
# 10670 acetaminophen   buta
# 10671 nexplanon birth cont
# 10672 bupropion   naltrexo
# 10673 implanon birth contr
# 10674 coreg high blood pre
# 10675 mirena birth control
# 10676 plaquenil sjogren ow
# 10677 duloxetine depressio
# 10678 meloxicam rheumatoid
# 10679 aluminum chloride he
# 10680 buprenorphine   nalo
# 10681 lo loestrin fe birth
# 10682 halcion insomnia my
# 10683 intuniv adhd my adop
# 10684 dextromethorphan cou
# 10685 levonorgestrel birth
# 10686 varenicline smoking
# 10687 famotidine gerd i ha
# 10688 lamotrigine bipolar
# 10689 acetaminophen   hydr
# 10690 armour thyroid under
# 10691 acetaminophen   oxyc
# 10692 clarithromycin sinus
# 10693 alprazolam panic dis
# 10694 larin fe 1   20 birt
# 10695 citalopram persisten
# 10696 seroquel bipolar dis
# 10697 phenergan nausea vom
# 10698 levonorgestrel birth
# 10699 oxycodone chronic pa
# 10700 silenor insomnia i h
# 10701 neurontin pain i had
# 10702 orlistat obesity i l
# 10703 amitriptyline anxiet
# 10704 seroquel xr depressi
# 10705 lortab rheumatoid ar
# 10706 lisdexamfetamine adh
# 10707 indomethacin gout  a
# 10708 fluoxetine anxiety a
# 10709 ethinyl estradiol
# 10710 norethindrone abnorm
# 10711 metaxalone muscle sp
# 10712 guaifenesin   pseudo
# 10713 nortriptyline migrai
# 10714 loperamide diarrhea
# 10715 loestrin 24 fe birth
# 10716 belsomra insomnia i
# 10717 levonorgestrel birth
# 10718 naltrexone alcohol d
# 10719 sertraline depressio
# 10720 pristiq depression i
# 10721 geodon bipolar disor
# 10722 gabapentin restless
# 10723 contrave obesity i
# 10724 glycerin constipatio
# 10725 duloxetine ibromyalg
# 10726 levofloxacin urinary
# 10727 paroxetine anxiety f
# 10728 cefuroxime lyme dise
# 10729 cymbalta ibromyalgia
# 10730 ethinyl estradiol
# 10731 lamictal bipolar dis
# 10732 estradiol atrophic v
# 10733 moviprep bowel prepa
# 10734 contrave obesity it
# 10735 sprintec birth contr
# 10736 buspirone panic diso
# 10737 tretinoin acne i sta
# 10738 adderall adhd i was
# 10739 lutera birth control
# 10740 liraglutide diabetes
# 10741 drospirenone   ethin
# 10742 ortho evra birth con
# 10743 phentermine weight l
# 10744 escitalopram general
# 10745 cyclizine motion sic
# 10746 plan b emergency con
# 10747 lisdexamfetamine adh
# 10748 mirabegron urinary i
# 10749 pramipexole restless
# 10750 drysol hyperhidrosis
# 10751 azelastine allergic
# 10752 sulfacetamide sodium
# 10753 clomipramine panic d
# 10754 varenicline smoking
# 10755 chantix smoking cess
# 10756 armodafinil narcolep
# 10757 tamoxifen breast can
# 10758 levonorgestrel birth
# 10759 arthrotec sciatica i
# dump

# %%
combine_name_use_review_df_test = pd.DataFrame(distill_bert_embedding_test, columns=[f"review_{i}" for i in range(768)])
combine_name_use_review_df_test.head(2)
# Out:
#    review_0  review_1  review_2  review_3  review_4  review_5  review_6  \
# 0 -0.019849  0.173974  0.128156 -0.329652 -0.305466 -0.374780  0.513443
# 1  0.079807  0.090857  0.170656 -0.152019 -0.202442 -0.290995  0.381226
#
#    review_7  review_8  review_9  ...  review_758  review_759  review_760  \
# 0  0.256115 -0.174848 -0.051410  ...   -0.111515   -0.228544   -0.033203
# 1  0.454116 -0.339259 -0.183735  ...   -0.072119   -0.301159   -0.060482
#
#    review_761  review_762  review_763  review_764  review_765  review_766  \
# 0   -0.091765    0.380650    0.049244   -0.215225   -0.279196    0.303954
# 1   -0.068246    0.254681    0.206014   -0.216410   -0.261225    0.255563
#
#    review_767
# 0    0.058522
# 1    0.014028
#
# [2 rows x 768 columns]

# %%
print("Number of features in preprocessed dataframe :", drug_test_data.shape[1])
print("Number of features in nlp dataframe :", combine_name_use_review_df_test.shape[1])
# Out:
# Number of features in preprocessed dataframe : 13
# Number of features in nlp dataframe : 768

# %%
# storing the final features to csv file
if not os.path.isfile('../ix_word/final_features_test.csv'):
    combine_name_use_review_df_test['patient_id']=drug_test_data['patient_id']
    combine_name_use_review_df['effectiveness_rating']=drug_test_data['effectiveness_rating']
    combine_name_use_review_df['drug_approved_by_UIC']=drug_test_data['drug_approved_by_UIC']
    combine_name_use_review_df_test['number_of_times_prescribed']=drug_test_data['number_of_times_prescribed']
    combine_name_use_review_df_test['len_review_by_patient_unique_word']=drug_test_data['len_review_by_patient_unique_word']
    first_column = combine_name_use_review_df_test.pop('patient_id')
    combine_name_use_review_df_test.insert(0, 'patient_id', first_column)
    combine_name_use_review_df_test.to_csv('../ix_word/final_features_test.csv')
